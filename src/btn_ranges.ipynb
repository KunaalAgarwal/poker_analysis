# %%
import importlib
import range_construction
importlib.reload(range_construction)
# Out:
# <module 'range_construction' from 'c:\\Users\\kuna8\\personal_projects\\poker_cash_ranges\\src\\range_construction.py'>

# %% [markdown]
# ## VPIP goal = ~55% sum(RFI, 3!, Flat)

# %% [markdown]
# ## RFI (Raise first in, Open) range

# %% [markdown]
# Only options from RFI are Raise/Fold. No open limping in my strategy.
#
# Playing a "merged" strategy. Rather than having a polarized range with a section of extremely strong value hands and extremely weak bluffs, I include bluffs as playable hands that are slightly weaker than my strongest hands.
#
# Range percent approximately = mean hand percentile indicates that a merged range has been used.
#
# A or K high percentage vitally important to be high. Targeting around 55%.
# Given the breakeven for a bluff as pot odds being laid after the bet and assuming that roughly 45% of our range is a bluff on A/K high boards. We can c-bet whole range for Half-pot profitably.

# %%
rfi_range = {
    # Pairs
    "AA": {"raise": 1.0, "call": 0.0},
    "KK": {"raise": 1.0, "call": 0.0},
    "QQ": {"raise": 1.0, "call": 0.0},
    "JJ": {"raise": 1.0, "call": 0.0},
    "TT": {"raise": 1.0, "call": 0.0},
    "99": {"raise": 1.0, "call": 0.0},
    "77": {"raise": 1.0, "call": 0.0},
    "88": {"raise": 1.0, "call": 0.0},
    "66": {"raise": 1.0, "call": 0.0},
    "55": {"raise": 1.0, "call": 0.0},
    "44": {"raise": 1.0, "call": 0.0},
    "33": {"raise": 1.0, "call": 0.0},
    "22": {"raise": 1.0, "call": 0.0},

    "AKs": {"raise": 1.0, "call": 0.0},
    "AQs": {"raise": 1.0, "call": 0.0},
    "AJs": {"raise": 1.0, "call": 0.0},
    "ATs": {"raise": 1.0, "call": 0.0},
    "A9s": {"raise": 1.0, "call": 0.0},
    "A8s": {"raise": 1.0, "call": 0.0},
    "A7s": {"raise": 1.0, "call": 0.0},
    "A6s": {"raise": 1.0, "call": 0.0},
    "A5s": {"raise": 1.0, "call": 0.0},
    "A4s": {"raise": 1.0, "call": 0.0},
    "A3s": {"raise": 1.0, "call": 0.0},
    "A2s": {"raise": 1.0, "call": 0.0},

    "AKo": {"raise": 1.0, "call": 0.0},
    "AQo": {"raise": 1.0, "call": 0.0},
    "AJo": {"raise": 1.0, "call": 0.0},
    "ATo": {"raise": 1.0, "call": 0.0},
    "A9o": {"raise": 1.0, "call": 0.0},
    "A8o": {"raise": 1.0, "call": 0.0},
    "A7o": {"raise": 1.0, "call": 0.0},
    "A5o": {"raise": 0.33, "call": 0.0},
    "A4o": {"raise": 0.33, "call": 0.0},
    "A3o": {"raise": 0.33, "call": 0.0},
    "A2o": {"raise": 0.33, "call": 0.0},

    "KQs": {"raise": 1.0, "call": 0.0},
    "KJs": {"raise": 1.0, "call": 0.0},
    "KTs": {"raise": 1.0, "call": 0.0},
    "K9s": {"raise": 1.0, "call": 0.0},
    "K8s": {"raise": 1.0, "call": 0.0},
    "K7s": {"raise": 0.5, "call": 0.0},
    "K6s": {"raise": 0.5, "call": 0.0},

    "KQo": {"raise": 1.0, "call": 0.0},
    "KJo": {"raise": 1.0, "call": 0.0},
    "KTo": {"raise": 1.0, "call": 0.0},
    "K9o": {"raise": 1.0, "call": 0.0},
    "K8o": {"raise": 1.0, "call": 0.0},
    "K7o": {"raise": 1.0, "call": 0.0},

    "QJs": {"raise": 1.0, "call": 0.0},
    "QTs": {"raise": 1.0, "call": 0.0},
    "Q9s": {"raise": 1.0, "call": 0.0},
    "Q8s": {"raise": 1.0, "call": 0.0},
    

    "QJo": {"raise": 1.0, "call": 0.0},
    "QTo": {"raise": 1.0, "call": 0.0},
    "Q9o": {"raise": 0.5, "call": 0.0},

    "JTs": {"raise": 1.0, "call": 0.0},
    "J9s": {"raise": 1.0, "call": 0.0},

    "JTo": {"raise": 1.0, "call": 0.0},
    "J9o": {"raise": 0.5, "call": 0.0},

    "T9s": {"raise": 1.0, "call": 0.0},
    "T8s": {"raise": 1.0, "call": 0.0},   

    "98s": {"raise": 1.0, "call": 0.0},
    "97s": {"raise": 1.0, "call": 0.0},

    "87s": {"raise": 1.0, "call": 0.0},
    "86s": {"raise": 0.5, "call": 0.0},

    "76s": {"raise": 0.75, "call": 0.0},
    "75s": {"raise": 0.33, "call": 0.0},

    "65s": {"raise": 0.5, "call": 0.0},
    
    "54s": {"raise": 0.5, "call": 0.0},

    "43s": {"raise": 0.5, "call": 0.0},

    "32s": {"raise": 0.5, "call": 0.0},
}
# Visualize the range
rfi = range_construction.generate_range(rfi_range, '../ranges/btn_ranges/btn_rfi.png')
rfi_distribution = range_construction.range_hand_distribution(rfi_range)
rfi_percent_by_actions = range_construction.range_percent_by_all_actions(rfi_range)
rfi_mean_hand_rank = range_construction.average_range_rank(rfi_range)


print(rfi_percent_by_actions)
print(f'Mean hand rank: {rfi_mean_hand_rank}')
print(f'Percent A or K high: {range_construction.percent_range_high_card(rfi_range)} %')

rfi_distribution[1].to_csv('../ranges/btn_ranges/btn_rfi_distribution.csv')
rfi_distribution[0]
# Out:
# {'raise': {'percent': 32.289592760180994, 'combos': 428.16}, 'call': {'percent': 0.0, 'combos': 0}, 'fold': {'percent': 67.710407239819, 'combos': 897.8399999999999}, 'overall': {'percent': 32.289592760180994, 'combos': 428.16}}
# Mean hand rank: 34.87916666666667
# Percent A or K high: 59.753363228699556 %
# count     72.000000
# mean      44.708333
# std       36.804561
# min        1.000000
# 25%       18.750000
# 50%       36.500000
# 75%       56.250000
# max      163.000000
# Name: Rank, dtype: float64

# %% [markdown]
# # 3! Response range

# %% [markdown]
# Determination of 3bet call range size via MDF. Assuming a 3bet sizing of around 3.5x (3x + dead money usually), alpha = (3.5 / 3.5 + 1 + dead money), MDF = 1 - (3.5 / 4.5 + dead money). MDF is approximately 30%. Thus we need to call with at minimum 30% of our BTN open range.
#
# Also consider value to bluff ratios. Pot odds with a 3.5x bet are:
# 2.5 / ((1 + 3.5 + dead money) + 2.5) = approximately 25%. People are often 3betting bluffing far more than 25% of the time however, but will also overcall 4bets (with marginal hands) and thus the best strategy is to play a polarized 4bet strategy and call 3bets at slightly higher than MDF.

# %% [markdown]
# 4bet range should be around 60% value, 40% bluffs. Have 36 value and 23 bluff combos.
# Leads to a 2.5x 4bet size from IP.

# %%
response_3bet_range = {
    # Pairs
    "AA": {"raise": 1.0, "call": 0.0}, 
    "KK": {"raise": 1.0, "call": 0.0}, 
    "QQ": {"raise": 1.0, "call": 0.0},
    "JJ": {"raise": 1/3, "call": 2/3}, 
    "TT": {"raise": 0.0, "call": 1.0}, 

    "99": {"raise": 0.0, "call": 1.0}, 
    "88": {"raise": 0.0, "call": 1.0},  
    "77": {"raise": 0.0, "call": 0.5},
    "66": {"raise": 0.0, "call": 0.0}, 
    "55": {"raise": 0.0, "call": 0.0},
    # 4bet bluff (unblocks AA, KK, QQ, JJ), can beat AK, AQ, high pressure on middling pairs
    "44": {"raise": 0.17, "call": 0.0}, 
    "33": {"raise": 0.17, "call": 0.0},  
    "22": {"raise": 0.5, "call": 0.0}, 

    "AKs": {"raise": 1.0, "call": 0.0},
    "AQs": {"raise": 0.5, "call": 0.5}, 
    "AJs": {"raise": 0.0, "call": 1.0},
    "ATs": {"raise": 0.0, "call": 1.0},
    "A9s": {"raise": 0.0, "call": 1.0},
    "A8s": {"raise": 0.0, "call": 0.5},
    "A7s": {"raise": 0.0, "call": 0.5},
    "A6s": {"raise": 0.0, "call": 0.0},
    "A5s": {"raise": 1.0, "call": 0.0}, # 4bet bluff
    "A4s": {"raise": 0.0, "call": 0.0},
    "A3s": {"raise": 0.0, "call": 0.0},
    "A2s": {"raise": 1.0, "call": 0.0}, # 4bet bluff

    "AKo": {"raise": .75, "call": 0.25},
    "AQo": {"raise": 0.0, "call": 1.0},
    "AJo": {"raise": 0.0, "call": 1.0},
    "ATo": {"raise": 0.0, "call": 1.0}, 
    "A9o": {"raise": 0.0, "call": 0.5},
    "A5o": {"raise": 0.33, "call": 0.0}, # come back to adjust bluff frequencies
    "A4o": {"raise": 0.0, "call": 0.0},
    "A3o": {"raise": 0.0, "call": 0.0},
    "A2o": {"raise": 0.33, "call": 0.0},

    "KQs": {"raise": 0.25, "call": 0.75},
    "KJs": {"raise": 0.0, "call": 1.0},
    "KTs": {"raise": 0.0, "call": 1.0},
    "K9s": {"raise": 0.0, "call": 1.0},
    "K8s": {"raise": 0.0, "call": 0.5},


    "KQo": {"raise": 0.0, "call": 1.0},
    "KJo": {"raise": 0.0, "call": 0.75},
    "KTo": {"raise": 0.0, "call": 0.0},

    "QJs": {"raise": 0.0, "call": 1.0},
    "QTs": {"raise": 0.0, "call": 0.5},

    "QJo": {"raise": 0.0, "call": 1.0},
    "QTo": {"raise": 0.0, "call": 0.0},
    "Q9o": {"raise": 0.0, "call": 0.0},

    "JTs": {"raise": 0.0, "call": 1.0},
    "J9s": {"raise": 0.0, "call": 0.5},

    "JTo": {"raise": 0.0, "call": 0.0},
    "J9o": {"raise": 0.0, "call": 0.0},

    "T9s": {"raise": 0.0, "call": 1.0},
    "T8s": {"raise": 0.0, "call": 0.5},   

    "98s": {"raise": 0.0, "call": 1.0},
    "97s": {"raise": 0.0, "call": 0.0},

    "87s": {"raise": 0.0, "call": 1.0},
    "86s": {"raise": 0.0, "call": 0.0},

    "76s": {"raise": 0.5, "call": 0.5},
    "75s": {"raise": 0.0, "call": 0.0},

    "65s": {"raise": 0.0, "call": 0.0},
}
# Visualize the range
response_3bet = range_construction.generate_range(response_3bet_range, '../ranges/btn_ranges/btn_3!response')
response_3bet_distribution = range_construction.range_hand_distribution(response_3bet_range)
response_3bet_percent_by_actions = range_construction.range_percent_by_all_actions(response_3bet_range)
response_3bet_mean_hand_rank = range_construction.average_range_rank(response_3bet_range)

defended_rfi = 100*response_3bet_percent_by_actions['overall']['combos'] / rfi_percent_by_actions['overall']['combos'] 

print(response_3bet_percent_by_actions)
print(f'Mean hand rank: {response_3bet_mean_hand_rank}')
print(f'Percent A or K high: {range_construction.percent_range_high_card(response_3bet_range)} %')
print(f'Percent of BTN RFI defended: {defended_rfi} %')

response_3bet_distribution[1].to_csv('../ranges/btn_ranges/btn_3bet_response_distribution.csv')
response_3bet_distribution[0]
# Out:
# {'raise': {'percent': 4.446455505279035, 'combos': 58.96}, 'call': {'percent': 12.518853695324283, 'combos': 166.0}, 'fold': {'percent': 83.03469079939669, 'combos': 1101.04}, 'overall': {'percent': 16.96530920060332, 'combos': 224.96}}
# Mean hand rank: 21.520204081632652
# Percent A or K high: 64.4203413940256 %
# Percent of BTN RFI defended: 52.54110612855007 %
# count     44.000000
# mean      31.750000
# std       27.175677
# min        1.000000
# 25%       11.750000
# 50%       24.000000
# 75%       42.000000
# max      115.000000
# Name: Rank, dtype: float64

# %% [markdown]
# # Open response range

# %% [markdown]
# Assuming open comes from CO for this range. Will tighten frequencies as the open gets earlier. To hit the 50% VPIP goal need 18% of combos across 3! and flat.

# %%
open_response_range = {
    # Pairs
    "AA": {"raise": 1.0, "call": 0.0},
    "KK": {"raise": 1.0, "call": 0.0},
    "QQ": {"raise": 1.0, "call": 0.0},
    "JJ": {"raise": 1.0, "call": 0.0},
    "TT": {"raise": 1.0, "call": 0.0},
    "99": {"raise": 1.0, "call": 0.0},
    "88": {"raise": 1.0, "call": 0.0},
    "77": {"raise": 0.66, "call": 0.33}, # lowering frequency on 77 and 66 slightly
    "66": {"raise": 0.5, "call": 0.5},
    "55": {"raise": 0.0, "call": 1.0}, # these low pocket pairs turn into folds quickly
    "44": {"raise": 0.0, "call": 1.0},
    "33": {"raise": 0.0, "call": 1.0},
    "22": {"raise": 0.0, "call": 1.0},

    "AKs": {"raise": 1.0, "call": 0.0},
    "AQs": {"raise": 1.0, "call": 0.0},
    "AJs": {"raise": 1.0, "call": 0.0},
    "ATs": {"raise": 0.75, "call": 0.25},
    "A9s": {"raise": 0.0, "call": 1.0},
    "A8s": {"raise": 0.0, "call": 1.0},
    "A7s": {"raise": 0.0, "call": 0.75},
    "A6s": {"raise": 0.0, "call": 0.5}, # these middling aces turn into folds quickly
    "A5s": {"raise": 0.5, "call": 0.0}, # 3bet bluffs
    "A4s": {"raise": 0.5, "call": 0.0},
    "A3s": {"raise": 0.5, "call": 0.0},
    "A2s": {"raise": 0.5, "call": 0.0}, 

    "AKo": {"raise": 0.75, "call": 0.25}, # keep some combos to uncap the flatting range
    "AQo": {"raise": 1.0, "call": 0.0},
    "AJo": {"raise": 0.75, "call": 0.25},
    "ATo": {"raise": 0.5, "call": 0.5}, # probably weakest AXo to 3bet
    "A9o": {"raise": 0.0, "call": 0.75},
    "A8o": {"raise": 0.0, "call": 0.5},

    "KQs": {"raise": 1.0, "call": 0.0},
    "KJs": {"raise": 1.0, "call": 0.0},
    "KTs": {"raise": 0.0, "call": 1.0},
    "K9s": {"raise": 0.0, "call": 0.75},
    "K8s": {"raise": 0.0, "call": 0.5},

    "KQo": {"raise": 1.0, "call": 0.0},
    "KJo": {"raise": 0.0, "call": 1.0},
    "KTo": {"raise": 0.0, "call": 0.5},
    "K9o": {"raise": 0.0, "call": 0.25},

    "QJs": {"raise": .75, "call": 0.25},
    "QTs": {"raise": 0.0, "call": 1.0},
    "Q9s": {"raise": 0.0, "call": 0.5},
    
    "QJo": {"raise": 0.0, "call": 1.0},
    "QTo": {"raise": 0.0, "call": 0},

    "JTs": {"raise": 1.0, "call": 0.0},
    "J9s": {"raise": 0.0, "call": 0.0}, 

    "JTo": {"raise": 1.0, "call": 0.0},
    "J9o": {"raise": 0.0, "call": 0.0},

    "T9s": {"raise": 1.0, "call": 0.0}, # 3bet bluff
    "T8s": {"raise": 0.0, "call": 0.5}, # this will fold to earlier   

    "98s": {"raise": 1.0, "call": 0.0}, # 3bet bluff
    "97s": {"raise": 0.0, "call": 0.5},

    "87s": {"raise": 1.0, "call": 0.0}, # 3bet bluff
    "86s": {"raise": 0.0, "call": 0.5},

    "76s": {"raise": 0.5, "call": 0.5},
    "75s": {"raise": 0.0, "call": 0.5},

    "65s": {"raise": 0.0, "call": 0.5}, 
    
    "54s": {"raise": 0.0, "call": 0.5},

    "43s": {"raise": 0.0, "call": 0.5},

    "32s": {"raise": 0.0, "call": 0.5},
}

# Visualize the range
open_response = range_construction.generate_range(open_response_range, '../ranges/btn_ranges/btn_open_response')
open_response_distribution = range_construction.range_hand_distribution(open_response_range)
open_response_percent_by_actions = range_construction.range_percent_by_all_actions(open_response_range)
open_response_mean_hand_rank = range_construction.average_range_rank(open_response_range)

print(open_response_percent_by_actions)
print(f'Mean hand rank: {open_response_mean_hand_rank}')
print(f'Percent A or K high: {range_construction.percent_range_high_card(open_response_range)} %')

open_response_distribution[1].to_csv('../ranges/btn_ranges/btn_open_response_distribution.csv')
open_response_distribution[0]
# Out:
# {'raise': {'percent': 12.138763197586727, 'combos': 160.96}, 'call': {'percent': 10.33031674208145, 'combos': 136.98000000000002}, 'fold': {'percent': 77.53092006033182, 'combos': 1028.06}, 'overall': {'percent': 22.46907993966818, 'combos': 297.94000000000005}}
# Mean hand rank: 27.081969696969697
# Percent A or K high: 54.373363764516334 %
# count     58.000000
# mean      43.000000
# std       40.714668
# min        1.000000
# 25%       15.250000
# 50%       29.500000
# 75%       53.250000
# max      163.000000
# Name: Rank, dtype: float64

# %% [markdown]
# # 4! response range

# %% [markdown]
# I will not be using a 5! range. This is because most players don't have enough 4! bluffs. Thus my 5! range would have to be mostly value (or merged) and merged is probably not great and only strong hands allows the opponents to exploitively fold even very strong hands.
#
# The other note is that my 4! response range will tend to include only my absolute strongest 3! hands, with obvious deviations for players who over 4bet.
#
# Most 4bet sizing results in an MDF of about 0.4 (~2x). Thus we need to only call with strongest 40% of range.

# %%
open_response_percent_by_actions['raise']['combos']
# Out:
# 160.96

# %%
response_4bet_range = {
    # Pairs
    "AA": {"raise": 0, "call": 1.0},
    "KK": {"raise": 0, "call": 1.0},
    "QQ": {"raise": 0, "call": 1.0},
    "JJ": {"raise": 0, "call": 1.0},
    "TT": {"raise": 0, "call": 1.0},
    "99": {"raise": 0, "call": 0.5},
    "88": {"raise": 0, "call": 0.0},

    "AKs": {"raise": 0, "call": 1.0},
    "AQs": {"raise": 0, "call": 0.75},
    "AJs": {"raise": 0, "call": 0.0},
    "ATs": {"raise": 0, "call": 0.0},

    "AKo": {"raise": 0.0, "call": 1.0}, # keep some combos to uncap the flatting range
    "AQo": {"raise": 0.0, "call": 0.0},
    "AJo": {"raise": 0.0, "call": 0.0},
    "ATo": {"raise": 0.0, "call": 0.0}, # probably weakest AXo to 3bet

    "KQs": {"raise": 0.0, "call": 0.5},
    "KJs": {"raise": 0.0, "call": 0.0},

    "KQo": {"raise": 0.0, "call": 0.0},

    "QJs": {"raise": 0.0, "call": 0.0},
    "JTs": {"raise": 0.0, "call": 0.0},
}

response_4bet = range_construction.generate_range(response_4bet_range, '../ranges/btn_ranges/btn_4!response.png')
response_4bet_distribution = range_construction.range_hand_distribution(response_4bet_range)
response_4bet_percent_by_actions = range_construction.range_percent_by_all_actions(response_4bet_range)
response_4bet_mean_hand_rank = range_construction.average_range_rank(response_4bet_range)

defended_3bet = 100*(response_4bet_percent_by_actions['overall']['combos'] / open_response_percent_by_actions['raise']['combos'])

print(response_4bet_percent_by_actions)
print(f'Mean hand rank: {response_4bet_mean_hand_rank}')
print(f'Percent A or K high: {range_construction.percent_range_high_card(response_4bet_range)} %')
print(f'3bet defended: {defended_3bet} %')

response_4bet_distribution[1].to_csv('../ranges/btn_ranges/btn_response_4bet_distribution.csv')
response_4bet_distribution[0]
# Out:
# {'raise': {'percent': 0.0, 'combos': 0}, 'call': {'percent': 4.072398190045249, 'combos': 54.0}, 'fold': {'percent': 95.92760180995475, 'combos': 1272.0}, 'overall': {'percent': 4.072398190045249, 'combos': 54.0}}
# Mean hand rank: 5.35
# Percent A or K high: 61.111111111111114 %
# 3bet defended: 33.54870775347912 %
# count    10.000000
# mean      6.700000
# std       4.785394
# min       1.000000
# 25%       3.250000
# 50%       5.500000
# 75%       9.500000
# max      16.000000
# Name: Rank, dtype: float64
