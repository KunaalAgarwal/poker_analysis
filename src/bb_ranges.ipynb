# %%
import importlib
import range_construction
importlib.reload(range_construction)
# Out:
# <module 'range_construction' from 'c:\\Users\\kuna8\\personal_projects\\poker_cash_ranges\\src\\range_construction.py'>

# %% [markdown]
# ## RFI (Raise first in, Open) range, late position limps

# %% [markdown]
# Late position limps or early position limps from players who are unlikely to limp raise

# %%
rfi_range_loose = {
    # =====================
    # Pairs
    # =====================
    "AA": {"raise": 1.0,  "call": 0.0},
    "KK": {"raise": 1.0,  "call": 0.0},
    "QQ": {"raise": 1.0,  "call": 0.0},
    "JJ": {"raise": 1.0,  "call": 0.0},
    "TT": {"raise": 1.0,  "call": 0.0},
    "99": {"raise": 1.0,  "call": 0.0},
    "88": {"raise": 1.0,  "call": 0.0},
    "77": {"raise": 1.0,  "call": 0.0},
    "66": {"raise": 1.0,  "call": 0.0},
    "55": {"raise": 1.0, "call": 0.0},
    "44": {"raise": 1.0,  "call": 0.0},
    "33": {"raise": 1.0,  "call": 0.0},
    "22": {"raise": 1.0,  "call": 0.0},

    # =====================
    # Suited Aces
    # =====================
    "AKs": {"raise": 1.0,  "call": 0.0},
    "AQs": {"raise": 1.0,  "call": 0.0},
    "AJs": {"raise": 1.0,  "call": 0.0},
    "ATs": {"raise": 1.0,  "call": 0.0},
    "A9s": {"raise": 1.0, "call": 0.0},
    "A8s": {"raise": 1.0,  "call": 0.0},
    "A7s": {"raise": 1.0, "call": 0.0},
    "A6s": {"raise": 1.0,  "call": 0.0},
    "A5s": {"raise": 1.0, "call": 0.0},
    "A4s": {"raise": 1.0, "call": 0.0},
    "A3s": {"raise": 1.0,  "call": 0.0},
    "A2s": {"raise": 1.0,  "call": 0.0},

    # =====================
    # Offsuit Aces
    # =====================
    "AKo": {"raise": 1.0,  "call": 0.0},
    "AQo": {"raise": 1.0, "call": 0.0},
    "AJo": {"raise": 1.0, "call": 0.0},
    "ATo": {"raise": 1.0, "call": 0.0},
    "A9o": {"raise": 1.0, "call": 0.0},
    "A8o": {"raise": 1.0,  "call": 0.0},
    "A7o": {"raise": 1.0,  "call": 0.0},
    "A6o": {"raise": 1.0,  "call": 0.0},
    "A5o": {"raise": 1.0,  "call": 0.0},
    "A4o": {"raise": 1.0,  "call": 0.0},
    "A3o": {"raise": 1.0,  "call": 0.0},
    "A2o": {"raise": 1.0,  "call": 0.0},

    # =====================
    # Suited Broadways
    # =====================
    "KQs": {"raise": 1.0,  "call": 0.0},  
    "KJs": {"raise": 1.0, "call": 0.0},
    "KTs": {"raise": 1.0, "call": 0.0},
    "QJs": {"raise": 1.0, "call": 0.0},
    "QTs": {"raise": 1.0, "call": 0.0},
    "JTs": {"raise": 1.0, "call": 0.0},

    # =====================
    # Other Suited Ks
    # =====================
    "K9s": {"raise": 1.0,  "call": 0.0},
    "K8s": {"raise": 1.0, "call": 0.0},
    "K7s": {"raise": 1.0,  "call": 0.0},
    "K6s": {"raise": 1.0,  "call": 0.0},
    "K5s": {"raise": 1.0,  "call": 0.0},
    "K4s": {"raise": 1.0,  "call": 0.0},
    "K3s": {"raise": 1.0,  "call": 0.0},
    "K2s": {"raise": 1.0,  "call": 0.0},

    # =====================
    # Other Suited Qs
    # =====================
    "Q9s": {"raise": 1.0,  "call": 0.0},
    "Q8s": {"raise": 1.0, "call": 0.0},
    "Q7s": {"raise": 1.0,  "call": 0.0},
    "Q6s": {"raise": 0.0,  "call": 1.0},
    "Q5s": {"raise": 0.0,  "call": 1.0},
    "Q4s": {"raise": 0.0,  "call": 1.0},
    "Q3s": {"raise": 0.0,  "call": 1.0},
    "Q2s": {"raise": 0.0,  "call": 1.0},

    # =====================
    # Other Suited Js
    # =====================
    "J9s": {"raise": 1.0, "call": 0.0},
    "J8s": {"raise": 1.0,  "call": 0.0},
    "J7s": {"raise": 0.0,  "call": 1.0},
    "J6s": {"raise": 0.0,  "call": 1.0},
    "J5s": {"raise": 0.0,  "call": 1.0},
    "J4s": {"raise": 0.0,  "call": 1.0},
    "J3s": {"raise": 0.0,  "call": 1.0},
    "J2s": {"raise": 0.0,  "call": 1.0},

    # =====================
    # Suited Connectors / Gappers
    # =====================
    "T9s": {"raise": 1.0, "call": 0.0},
    "T8s": {"raise": 1.0,  "call": 0.0},
    "T7s": {"raise": 0.0, "call": 1.0},
    "T6s": {"raise": 0.0,  "call": 1.0},
    "T5s": {"raise": 0.0,  "call": 1.0},
    "T4s": {"raise": 0.0,  "call": 1.0},
    "T3s": {"raise": 0.0,  "call": 1.0},
    "T2s": {"raise": 0.0,  "call": 1.0},

    "98s": {"raise": 1.0,  "call": 0.0},
    "97s": {"raise": 1.0, "call": 0.0},
    "96s": {"raise": 0.0,  "call": 1.0},
    "95s": {"raise": 0.0,  "call": 1.0},
    "94s": {"raise": 0.0,  "call": 1.0},
    "93s": {"raise": 0.0,  "call": 1.0},
    "92s": {"raise": 0.0,  "call": 1.0},

    "87s": {"raise": 1.0, "call": 0.0},
    "86s": {"raise": 0.0,  "call": 1.0},
    "85s": {"raise": 0.0,  "call": 1.0},
    "84s": {"raise": 0.0,  "call": 1.0},
    "83s": {"raise": 0.0,  "call": 1.0},
    "82s": {"raise": 0.0,  "call": 1.0},

    "76s": {"raise": 1.0, "call": 0.0},
    "75s": {"raise": 0.0,  "call": 1.0},
    "74s": {"raise": 0.0,  "call": 1.0},
    "73s": {"raise": 0.0,  "call": 1.0},
    "72s": {"raise": 0.0,  "call": 1.0},

    "65s": {"raise": 1.0, "call": 0.0},
    "64s": {"raise": 0.0,  "call": 1.0},
    "63s": {"raise": 0.0,  "call": 1.0},
    "62s": {"raise": 0.0,  "call": 1.0},

    "54s": {"raise": 1.0,  "call": 0.0},
    "53s": {"raise": 0.0,  "call": 1.0},
    "52s": {"raise": 0.0,  "call": 1.0},

    "43s": {"raise": 0.0,  "call": 1.0},
    "42s": {"raise": 0.0,  "call": 1.0},
    "32s": {"raise": 0.0,  "call": 1.0},

    # =====================
    # Offsuit Broadways
    # =====================
    "KQo": {"raise": 1.0, "call": 0.0},
    "KJo": {"raise": 1.0, "call": 0.0},
    "KTo": {"raise": 1.0,  "call": 0.0},
    "K9o": {"raise": 1.0,  "call": 0.0},
    "K8o": {"raise": 1.0,  "call": 0.0},
    "K7o": {"raise": 1.0,  "call": 0.0},
    "K6o": {"raise": 0.0,  "call": 1.0},
    "K5o": {"raise": 0.0,  "call": 1.0},
    "K4o": {"raise": 0.0,  "call": 1.0},
    "K3o": {"raise": 0.0,  "call": 1.0},
    "K2o": {"raise": 0.0,  "call": 1.0},

    "QJo": {"raise": 1.0, "call": 0.0},
    "QTo": {"raise": 1.0, "call": 0.0},
    "Q9o": {"raise": 1.0,  "call": 0.0},
    "Q8o": {"raise": 0.0,  "call": 1.0},
    "Q7o": {"raise": 0.0,  "call": 1.0},
    "Q6o": {"raise": 0.0,  "call": 1.0},
    "Q5o": {"raise": 0.0,  "call": 1.0},
    "Q4o": {"raise": 0.0,  "call": 1.0},
    "Q3o": {"raise": 0.0,  "call": 1.0},
    "Q2o": {"raise": 0.0,  "call": 1.0},

    "JTo": {"raise": 1.0, "call": 0.0},
    "J9o": {"raise": 1.0, "call": 0.0},
    "J8o": {"raise": 0.0,  "call": 1.0},
    "J7o": {"raise": 0.0,  "call": 1.0},
    "J6o": {"raise": 0.0,  "call": 1.0},
    "J5o": {"raise": 0.0,  "call": 1.0},
    "J4o": {"raise": 0.0,  "call": 1.0},
    "J3o": {"raise": 0.0,  "call": 1.0},
    "J2o": {"raise": 0.0,  "call": 1.0},

    # =====================
    # Other Offsuit Combos
    # =====================
    "T9o": {"raise": 1/3, "call": 2/3},
    "T8o": {"raise": 1/3, "call": 2/3},
    "T7o": {"raise": 0.0,  "call": 1.0},
    "T6o": {"raise": 0.0,  "call": 1.0},
    "T5o": {"raise": 0.0,  "call": 1.0},
    "T4o": {"raise": 0.0,  "call": 1.0},
    "T3o": {"raise": 0.0,  "call": 1.0},
    "T2o": {"raise": 0.0,  "call": 1.0},

    "98o": {"raise": 0.0, "call": 1.0},
    "97o": {"raise": 0.0,  "call": 1.0},
    "96o": {"raise": 0.0,  "call": 1.0},
    "95o": {"raise": 0.0,  "call": 1.0},
    "94o": {"raise": 0.0,  "call": 1.0},
    "93o": {"raise": 0.0,  "call": 1.0},
    "92o": {"raise": 0.0,  "call": 1.0},

    "87o": {"raise": 0.0,  "call": 1.0},
    "86o": {"raise": 0.0,  "call": 1.0},
    "85o": {"raise": 0.0,  "call": 1.0},
    "84o": {"raise": 0.0,  "call": 1.0},
    "83o": {"raise": 0.0,  "call": 1.0},
    "82o": {"raise": 0.0,  "call": 1.0},

    "76o": {"raise": 0.0,  "call": 1.0},
    "75o": {"raise": 0.0,  "call": 1.0},
    "74o": {"raise": 0.0,  "call": 1.0},
    "73o": {"raise": 0.0,  "call": 1.0},
    "72o": {"raise": 0.0,  "call": 1.0},

    "65o": {"raise": 0.0,  "call": 1.0},
    "64o": {"raise": 0.0,  "call": 1.0},
    "63o": {"raise": 0.0,  "call": 1.0},
    "62o": {"raise": 0.0,  "call": 1.0},

    "54o": {"raise": 0.0,  "call": 1.0},
    "53o": {"raise": 0.0,  "call": 1.0},
    "52o": {"raise": 0.0,  "call": 1.0},

    "43o": {"raise": 0.0,  "call": 1.0},
    "42o": {"raise": 0.0,  "call": 1.0},
    "32o": {"raise": 0.0,  "call": 1.0}
}


# Visualize the range
rfi = range_construction.generate_range(rfi_range_loose, '../ranges/bb_ranges/bb_rfi_loose.png')
rfi_distribution = range_construction.range_hand_distribution(rfi_range_loose)
rfi_percent_by_actions = range_construction.range_percent_by_all_actions(rfi_range_loose)
rfi_mean_hand_rank = range_construction.average_range_rank(rfi_range_loose)


print(rfi_percent_by_actions)
print(f'Mean hand rank: {rfi_mean_hand_rank}')
print(f'Percent A or K high: {range_construction.percent_range_high_card(rfi_range_loose)} %')

rfi_distribution[1].to_csv('../ranges/bb_ranges/bb_rfi_loose_distribution.csv')
rfi_distribution[0]
# Out:
# {'raise': {'percent': 39.06485671191554, 'combos': 518.0}, 'call': {'percent': 60.93514328808446, 'combos': 808.0}, 'fold': {'percent': 0.0, 'combos': 0.0}, 'overall': {'percent': 100.0, 'combos': 1326.0}}
# Mean hand rank: 84.00584795321637
# Percent A or K high: 28.657616892911008 %
# count    169.000000
# mean      85.000000
# std       48.930222
# min        1.000000
# 25%       43.000000
# 50%       85.000000
# 75%      127.000000
# max      169.000000
# Name: Rank, dtype: float64

# %%
rfi_range_tight = {
    # =====================
    # Pairs
    # =====================
    "AA": {"raise": 1.0,  "call": 0.0},
    "KK": {"raise": 1.0,  "call": 0.0},
    "QQ": {"raise": 1.0,  "call": 0.0},
    "JJ": {"raise": 1.0,  "call": 0.0},
    "TT": {"raise": 1.0,  "call": 0.0},
    "99": {"raise": 1.0,  "call": 0.0},
    "88": {"raise": 1.0,  "call": 0.0},
    "77": {"raise": 1.0,  "call": 0.0},
    "66": {"raise": 0.5,  "call": 0.5},
    "55": {"raise": 0.33, "call": 0.67},
    "44": {"raise": 0.0,  "call": 1.0},
    "33": {"raise": 0.0,  "call": 1.0},
    "22": {"raise": 0.0,  "call": 1.0},

    # =====================
    # Suited Aces
    # =====================
    "AKs": {"raise": 1.0,  "call": 0.0},
    "AQs": {"raise": 1.0,  "call": 0.0},
    "AJs": {"raise": 1.0,  "call": 0.0},
    "ATs": {"raise": 1.0,  "call": 0.0},
    "A9s": {"raise": 0.66, "call": 0.34},
    "A8s": {"raise": 0.5,  "call": 0.5},
    "A7s": {"raise": 0.33, "call": 0.67},
    "A6s": {"raise": 0.0,  "call": 1.0},
    "A5s": {"raise": 0.33, "call": 0.67},
    "A4s": {"raise": 0.33, "call": 0.67},
    "A3s": {"raise": 0.33,  "call": 0.67},
    "A2s": {"raise": 0.33,  "call": 0.67},

    # =====================
    # Offsuit Aces
    # =====================
    "AKo": {"raise": 1.0,  "call": 0.0},
    "AQo": {"raise": 0.75, "call": 0.25},
    "AJo": {"raise": 0.66, "call": 0.34},
    "ATo": {"raise": 0.33, "call": 0.67},
    "A9o": {"raise": 0.33, "call": 0.67},
    "A8o": {"raise": 0.0,  "call": 1.0},
    "A7o": {"raise": 0.0,  "call": 1.0},
    "A6o": {"raise": 0.0,  "call": 1.0},
    "A5o": {"raise": 0.0,  "call": 1.0},
    "A4o": {"raise": 0.0,  "call": 1.0},
    "A3o": {"raise": 0.0,  "call": 1.0},
    "A2o": {"raise": 0.0,  "call": 1.0},

    # =====================
    # Suited Broadways
    # =====================
    "KQs": {"raise": 1.0,  "call": 0.0},
    "KJs": {"raise": 0.66, "call": 0.34},
    "KTs": {"raise": 0.66, "call": 0.34},
    "QJs": {"raise": 0.66, "call": 0.34},
    "QTs": {"raise": 0.66, "call": 0.34},
    "JTs": {"raise": 0.66, "call": 0.34},

    # =====================
    # Other Suited Ks
    # =====================
    "K9s": {"raise": 0.5,  "call": 0.5},
    "K8s": {"raise": 0.33, "call": 0.67},
    "K7s": {"raise": 0.0,  "call": 1.0},
    "K6s": {"raise": 0.0,  "call": 1.0},
    "K5s": {"raise": 0.0,  "call": 1.0},
    "K4s": {"raise": 0.0,  "call": 1.0},
    "K3s": {"raise": 0.0,  "call": 1.0},
    "K2s": {"raise": 0.0,  "call": 1.0},

    # =====================
    # Other Suited Qs
    # =====================
    "Q9s": {"raise": 0.5,  "call": 0.5},
    "Q8s": {"raise": 0.33, "call": 0.67},
    "Q7s": {"raise": 0.0,  "call": 1.0},
    "Q6s": {"raise": 0.0,  "call": 1.0},
    "Q5s": {"raise": 0.0,  "call": 1.0},
    "Q4s": {"raise": 0.0,  "call": 1.0},
    "Q3s": {"raise": 0.0,  "call": 1.0},
    "Q2s": {"raise": 0.0,  "call": 1.0},

    # =====================
    # Other Suited Js
    # =====================
    "J9s": {"raise": 0.33, "call": 0.67},
    "J8s": {"raise": 0.0,  "call": 1.0},
    "J7s": {"raise": 0.0,  "call": 1.0},
    "J6s": {"raise": 0.0,  "call": 1.0},
    "J5s": {"raise": 0.0,  "call": 1.0},
    "J4s": {"raise": 0.0,  "call": 1.0},
    "J3s": {"raise": 0.0,  "call": 1.0},
    "J2s": {"raise": 0.0,  "call": 1.0},

    # =====================
    # Suited Connectors / Gappers
    # =====================
    "T9s": {"raise": 0.66, "call": 0.34},
    "T8s": {"raise": 0.5,  "call": 0.5},
    "T7s": {"raise": 0.33, "call": 0.67},
    "T6s": {"raise": 0.0,  "call": 1.0},
    "T5s": {"raise": 0.0,  "call": 1.0},
    "T4s": {"raise": 0.0,  "call": 1.0},
    "T3s": {"raise": 0.0,  "call": 1.0},
    "T2s": {"raise": 0.0,  "call": 1.0},

    "98s": {"raise": 0.5,  "call": 0.5},
    "97s": {"raise": 0.33, "call": 0.67},
    "96s": {"raise": 0.0,  "call": 1.0},
    "95s": {"raise": 0.0,  "call": 1.0},
    "94s": {"raise": 0.0,  "call": 1.0},
    "93s": {"raise": 0.0,  "call": 1.0},
    "92s": {"raise": 0.0,  "call": 1.0},

    "87s": {"raise": 0.33, "call": 0.67},
    "86s": {"raise": 0.0,  "call": 1.0},
    "85s": {"raise": 0.0,  "call": 1.0},
    "84s": {"raise": 0.0,  "call": 1.0},
    "83s": {"raise": 0.0,  "call": 1.0},
    "82s": {"raise": 0.0,  "call": 1.0},

    "76s": {"raise": 0.33, "call": 0.67},
    "75s": {"raise": 0.0,  "call": 1.0},
    "74s": {"raise": 0.0,  "call": 1.0},
    "73s": {"raise": 0.0,  "call": 1.0},
    "72s": {"raise": 0.0,  "call": 1.0},

    "65s": {"raise": 0.33, "call": 0.67},
    "64s": {"raise": 0.0,  "call": 1.0},
    "63s": {"raise": 0.0,  "call": 1.0},
    "62s": {"raise": 0.0,  "call": 1.0},

    "54s": {"raise": 0.0,  "call": 1.0},
    "53s": {"raise": 0.0,  "call": 1.0},
    "52s": {"raise": 0.0,  "call": 1.0},

    "43s": {"raise": 0.0,  "call": 1.0},
    "42s": {"raise": 0.0,  "call": 1.0},
    "32s": {"raise": 0.0,  "call": 1.0},

    # =====================
    # Offsuit Broadways
    # =====================
    "KQo": {"raise": 0.66, "call": 0.34},
    "KJo": {"raise": 0.33, "call": 0.67},
    "KTo": {"raise": 0.0,  "call": 1.0},
    "K9o": {"raise": 0.0,  "call": 1.0},
    "K8o": {"raise": 0.0,  "call": 1.0},
    "K7o": {"raise": 0.0,  "call": 1.0},
    "K6o": {"raise": 0.0,  "call": 1.0},
    "K5o": {"raise": 0.0,  "call": 1.0},
    "K4o": {"raise": 0.0,  "call": 1.0},
    "K3o": {"raise": 0.0,  "call": 1.0},
    "K2o": {"raise": 0.0,  "call": 1.0},

    "QJo": {"raise": 0.33, "call": 0.67},
    "QTo": {"raise": 0.33, "call": 0.67},
    "Q9o": {"raise": 0.0,  "call": 1.0},
    "Q8o": {"raise": 0.0,  "call": 1.0},
    "Q7o": {"raise": 0.0,  "call": 1.0},
    "Q6o": {"raise": 0.0,  "call": 1.0},
    "Q5o": {"raise": 0.0,  "call": 1.0},
    "Q4o": {"raise": 0.0,  "call": 1.0},
    "Q3o": {"raise": 0.0,  "call": 1.0},
    "Q2o": {"raise": 0.0,  "call": 1.0},

    "JTo": {"raise": 0.33, "call": 0.67},
    "J9o": {"raise": 0.33, "call": 0.67},
    "J8o": {"raise": 0.0,  "call": 1.0},
    "J7o": {"raise": 0.0,  "call": 1.0},
    "J6o": {"raise": 0.0,  "call": 1.0},
    "J5o": {"raise": 0.0,  "call": 1.0},
    "J4o": {"raise": 0.0,  "call": 1.0},
    "J3o": {"raise": 0.0,  "call": 1.0},
    "J2o": {"raise": 0.0,  "call": 1.0},

    # =====================
    # Other Offsuit Combos
    # =====================
    "T9o": {"raise": 0.33, "call": 0.67},
    "T8o": {"raise": 0.33, "call": 0.67},
    "T7o": {"raise": 0.0,  "call": 1.0},
    "T6o": {"raise": 0.0,  "call": 1.0},
    "T5o": {"raise": 0.0,  "call": 1.0},
    "T4o": {"raise": 0.0,  "call": 1.0},
    "T3o": {"raise": 0.0,  "call": 1.0},
    "T2o": {"raise": 0.0,  "call": 1.0},

    "98o": {"raise": 0.33, "call": 0.67},
    "97o": {"raise": 0.0,  "call": 1.0},
    "96o": {"raise": 0.0,  "call": 1.0},
    "95o": {"raise": 0.0,  "call": 1.0},
    "94o": {"raise": 0.0,  "call": 1.0},
    "93o": {"raise": 0.0,  "call": 1.0},
    "92o": {"raise": 0.0,  "call": 1.0},

    "87o": {"raise": 0.0,  "call": 1.0},
    "86o": {"raise": 0.0,  "call": 1.0},
    "85o": {"raise": 0.0,  "call": 1.0},
    "84o": {"raise": 0.0,  "call": 1.0},
    "83o": {"raise": 0.0,  "call": 1.0},
    "82o": {"raise": 0.0,  "call": 1.0},

    "76o": {"raise": 0.0,  "call": 1.0},
    "75o": {"raise": 0.0,  "call": 1.0},
    "74o": {"raise": 0.0,  "call": 1.0},
    "73o": {"raise": 0.0,  "call": 1.0},
    "72o": {"raise": 0.0,  "call": 1.0},

    "65o": {"raise": 0.0,  "call": 1.0},
    "64o": {"raise": 0.0,  "call": 1.0},
    "63o": {"raise": 0.0,  "call": 1.0},
    "62o": {"raise": 0.0,  "call": 1.0},

    "54o": {"raise": 0.0,  "call": 1.0},
    "53o": {"raise": 0.0,  "call": 1.0},
    "52o": {"raise": 0.0,  "call": 1.0},

    "43o": {"raise": 0.0,  "call": 1.0},
    "42o": {"raise": 0.0,  "call": 1.0},
    "32o": {"raise": 0.0,  "call": 1.0}
}

# Visualize the range
rfi = range_construction.generate_range(rfi_range_tight, '../ranges/bb_ranges/bb_rfi_tight.png')
rfi_distribution = range_construction.range_hand_distribution(rfi_range_tight)
rfi_percent_by_actions_tight = range_construction.range_percent_by_all_actions(rfi_range_tight)
rfi_mean_hand_rank = range_construction.average_range_rank(rfi_range_tight)


print(rfi_percent_by_actions_tight)
print(f'Mean hand rank: {rfi_mean_hand_rank}')
print(f'Percent A or K high: {range_construction.percent_range_high_card(rfi_range_tight)} %')

rfi_distribution[1].to_csv('../ranges/bb_ranges/bb_rfi_tight_distribution.csv')
rfi_distribution[0]
# Out:
# {'raise': {'percent': 14.710407239818995, 'combos': 195.0599999999999}, 'call': {'percent': 85.289592760181, 'combos': 1130.94}, 'fold': {'percent': 1.4210854715202004e-14, 'combos': 0.0}, 'overall': {'percent': 100.0, 'combos': 1326.0}}
# Mean hand rank: 68.73205741626795
# Percent A or K high: 28.657616892911008 %
# count    169.000000
# mean      85.000000
# std       48.930222
# min        1.000000
# 25%       43.000000
# 50%       85.000000
# 75%      127.000000
# max      169.000000
# Name: Rank, dtype: float64

# %% [markdown]
# ## 3! Response range

# %%
response_3bet_range = {
    # Pairs
    "AA": {"raise": 1.0, "call": 0.0}, 
    "KK": {"raise": 1.0, "call": 0.0}, 
    "QQ": {"raise": 1.0, "call": 0.0},
    "JJ": {"raise": 1.0, "call": 0.0}, 
    "TT": {"raise": 0.66, "call": 0.33}, 
    "99": {"raise": 0.33, "call": 0.66}, 
    "88": {"raise": 0.33, "call": 0.66},  
    "77": {"raise": 0.0, "call": 0.0},
    "66": {"raise": 0.0, "call": 0.0}, 
    "55": {"raise": 0.0, "call": 0.0},
    # 4bet bluff (unblocks AK, AQ, AJ, KQ, etc.), while ahead of those hands and can put high pressure on middling pairs
    "44": {"raise": 0.0, "call": 0.0}, 
    "33": {"raise": 0.0, "call": 0.0},  
    "22": {"raise": 0.0, "call": 0.0}, 

    "AKs": {"raise": 1.0, "call": 0.0},
    "AQs": {"raise": 0.5, "call": 0.5}, 
    "AJs": {"raise": 0.0, "call": 0.25},
    "ATs": {"raise": 0.0, "call": 0.0},
    "A9s": {"raise": 0.0, "call": 0.0},
    "A8s": {"raise": 0.0, "call": 0.0},
    "A7s": {"raise": 0.0, "call": 0.0},
    "A6s": {"raise": 0.0, "call": 0.0},
    "A5s": {"raise": 0.5, "call": 0.0}, # 4bet bluff
    "A4s": {"raise": 0.5, "call": 0.0},
    "A3s": {"raise": 0.5, "call": 0.0},
    "A2s": {"raise": 0.5, "call": 0.0}, # 4bet bluff

    "AKo": {"raise": 0.75, "call": 0.25},
    "AQo": {"raise": 0.0, "call": 1.0},
    "AJo": {"raise": 0.0, "call": 0.0},
    "ATo": {"raise": 0.0, "call": 0.0}, 
    "A9o": {"raise": 0.0, "call": 0.0},

    "A5o": {"raise": 0.0, "call": 0.0}, # come back to adjust bluff frequencies
    "A4o": {"raise": 0.0, "call": 0.0},
    "A3o": {"raise": 0.0, "call": 0.0},
    "A2o": {"raise": 0.0, "call": 0.0},

    "KQs": {"raise": 0.25, "call": 0.75},
    "KJs": {"raise": 0.0, "call": 0.0},
    "KTs": {"raise": 0.0, "call": 0.0},
    "K9s": {"raise": 0.0, "call": 0.0},

    "KQo": {"raise": 0.0, "call": 1.0},
    "KJo": {"raise": 0.0, "call": 0.0},
    "KTo": {"raise": 0.0, "call": 0.0},

    "QJs": {"raise": 0.0, "call": 1.0},
    "QTs": {"raise": 0.0, "call": 0.0},

    "QJo": {"raise": 0.0, "call": 0.0},
    "QTo": {"raise": 0.0, "call": 0.0},
    "Q9o": {"raise": 0.0, "call": 0.0},

    "JTs": {"raise": 0.0, "call": 1.0},
    "J9s": {"raise": 0.0, "call": 0.0},

    "JTo": {"raise": 0.0, "call": 0.0},
    "J9o": {"raise": 0.0, "call": 0.0},

    "T9s": {"raise": 0.0, "call": 0.5},
    "T8s": {"raise": 0.0, "call": 0.0},   

    "98s": {"raise": 0.0, "call": 0.5},
    "97s": {"raise": 0.0, "call": 0.0},

    "87s": {"raise": 0.0, "call": 0.0},
    "86s": {"raise": 0.0, "call": 0.0},

    "76s": {"raise": 0.0, "call": 0.0},
    "75s": {"raise": 0.0, "call": 0.0},

    "65s": {"raise": 0.0, "call": 0.0},
}
# Visualize the range
response_3bet = range_construction.generate_range(response_3bet_range, '../ranges/bb_ranges/bb_3!response.png')
response_3bet_distribution = range_construction.range_hand_distribution(response_3bet_range)
response_3bet_percent_by_actions = range_construction.range_percent_by_all_actions(response_3bet_range)
response_3bet_mean_hand_rank = range_construction.average_range_rank(response_3bet_range)

defended_rfi = 100*response_3bet_percent_by_actions['overall']['combos'] / rfi_percent_by_actions_tight['raise']['combos'] 

print(response_3bet_percent_by_actions)
print(f'Mean hand rank: {response_3bet_mean_hand_rank}')
print(f'Percent A or K high: {range_construction.percent_range_high_card(response_3bet_range)} %')
print(f'Percent of BB RFI defended: {defended_rfi} %')

response_3bet_distribution[1].to_csv('../ranges/bb_ranges/bb_3bet_response_distribution.csv')
response_3bet_distribution[0]
# Out:
# {'raise': {'percent': 4.217194570135747, 'combos': 55.92}, 'call': {'percent': 4.140271493212669, 'combos': 54.9}, 'fold': {'percent': 91.64253393665159, 'combos': 1215.1799999999998}, 'overall': {'percent': 8.357466063348417, 'combos': 110.82}}
# Mean hand rank: 11.734642857142857
# Percent A or K high: 62.26312939902545 %
# Percent of BB RFI defended: 56.81328821900957 %
# count    22.000000
# mean     22.090909
# std      21.661704
# min       1.000000
# 25%       6.250000
# 50%      13.000000
# 75%      34.000000
# max      83.000000
# Name: Rank, dtype: float64

# %% [markdown]
# # Open response range

# %% [markdown]
# Similar to the RFI range using two open response ranges one for tight opens (early position) and one for loose opens (late position)

# %%
open_response_range_tight = {
    # Pairs
    "AA": {"raise": 1.0, "call": 0.0},
    "KK": {"raise": 1.0, "call": 0.0},
    "QQ": {"raise": 1.0, "call": 0.0},
    "JJ": {"raise": 1.0, "call": 0.0},
    "TT": {"raise": 2/3, "call": 1/3},
    "99": {"raise": 0.0, "call": 1.0},
    "88": {"raise": 0.0, "call": 0.5},
    "77": {"raise": 0.0, "call": 0.5}, 
    "66": {"raise": 0.0, "call": 0.0},
    "55": {"raise": 0.0, "call": 0.0}, 
    "44": {"raise": 0.0, "call": 0.0},
    "33": {"raise": 0.0, "call": 0.0},
    "22": {"raise": 0.0, "call": 0.0},

    "AKs": {"raise": 1.0, "call": 0.0},
    "AQs": {"raise": 1/3, "call": 2/3},
    "AJs": {"raise": 0.0, "call": 0.5},
    "ATs": {"raise": 0.0, "call": 1/3},
    "A9s": {"raise": 0.0, "call": 0.0},
    "A8s": {"raise": 0.0, "call": 0.0},
    "A7s": {"raise": 0.0, "call": 0.0},
    "A6s": {"raise": 0.0, "call": 0.0}, # these middling aces turn into folds quickly
    "A5s": {"raise": 0.0, "call": 0.0}, # 3bet bluffs
    "A4s": {"raise": 0.0, "call": 0.0},
    "A3s": {"raise": 0.0, "call": 0.0},
    "A2s": {"raise": 0.0, "call": 0.0}, 

    "AKo": {"raise": 1.0, "call": 0.0}, # OOP raising is far better
    "AQo": {"raise": 0.5, "call": 0.5}, 
    "AJo": {"raise": 0.0, "call": 0.5},     
    "ATo": {"raise": 0.0, "call": 1/3}, 
    "A9o": {"raise": 0.0, "call": 0.0}, 
    "A8o": {"raise": 0.0, "call": 0.0},  

    "KQs": {"raise": 1.0, "call": 0.0},
    "KJs": {"raise": 0.0, "call": 0.5},
    "KTs": {"raise": 0.0, "call": 0.0},
    "K9s": {"raise": 0.0, "call": 0.0},
    "K8s": {"raise": 0.0, "call": 0.0},

    "KQo": {"raise": 0.5, "call": 0.5},
    "KJo": {"raise": 0.0, "call": 0.0},
    "KTo": {"raise": 0.0, "call": 0.0},
    "K9o": {"raise": 0.0, "call": 0.0},

    "QJs": {"raise": 0.0, "call": 0.5},
    "QTs": {"raise": 0.0, "call": 0.0},
    "Q9s": {"raise": 0.0, "call": 0.0},
    
    "QJo": {"raise": 0.0, "call": 0.0},
    "QTo": {"raise": 0.0, "call": 0.0},

    "JTs": {"raise": 0.0, "call": 1.0},
    "J9s": {"raise": 0.0, "call": 0.0}, 

    "JTo": {"raise": 0.0, "call": 0.0},
    "J9o": {"raise": 0.0, "call": 0.0},

    "T9s": {"raise": 0.0, "call": 1.0}, 
    "T8s": {"raise": 0.0, "call": 0.0},  

    "98s": {"raise": 0.0, "call": 0.5}, 
    "97s": {"raise": 0.0, "call": 0.0},

    "87s": {"raise": 0.0, "call": 1/3},
    "86s": {"raise": 0.0, "call": 0.0},

    "76s": {"raise": 0.0, "call": 0.0},
    "75s": {"raise": 0.0, "call": 0.0},

    "65s": {"raise": 0.0, "call": 0.0}, 
    
    "54s": {"raise": 0.0, "call": 0.0},

    "43s": {"raise": 0.0, "call": 0.0},

    "32s": {"raise": 0.0, "call": 0.0},
}

# Visualize the range
open_response_tight = range_construction.generate_range(open_response_range_tight, '../ranges/bb_ranges/bb_open_response_tight')
open_response_distribution_tight = range_construction.range_hand_distribution(open_response_range_tight)
open_response_percent_by_actions_tight = range_construction.range_percent_by_all_actions(open_response_range_tight)
open_response_mean_hand_rank = range_construction.average_range_rank(open_response_range_tight)

print(open_response_percent_by_actions_tight)
print(f'Mean hand rank: {open_response_mean_hand_rank}')
print(f'Percent A or K high: {range_construction.percent_range_high_card(open_response_range_tight)} %')

open_response_distribution_tight[1].to_csv('../ranges/bb_ranges/bb_open_response_distribution_tight.csv')
open_response_distribution_tight[0]
# Out:
# {'raise': {'percent': 4.625439919557567, 'combos': 61.333333333333336}, 'call': {'percent': 4.323780794369029, 'combos': 57.333333333333336}, 'fold': {'percent': 91.0507792860734, 'combos': 1207.3333333333335}, 'overall': {'percent': 8.949220713926596, 'combos': 118.66666666666667}}
# Mean hand rank: 11.958333333333332
# Percent A or K high: 63.48314606741572 %
# count     24.000000
# mean      21.250000
# std       25.541526
# min        1.000000
# 25%        6.750000
# 50%       12.500000
# 75%       20.250000
# max      100.000000
# Name: Rank, dtype: float64

# %%
open_response_range_loose = {
    # =====================
    # Pairs
    # =====================
    "AA": {"raise": 1.0,  "call": 0.0},
    "KK": {"raise": 1.0,  "call": 0.0},
    "QQ": {"raise": 1.0,  "call": 0.0},
    "JJ": {"raise": 1.0,  "call": 0.0},
    "TT": {"raise": 1.0,  "call": 0.0},
    "99": {"raise": 2/3, "call": 1/3},  
    "88": {"raise": 0.5, "call": 0.5},
    "77": {"raise": 0.0,  "call": 1.0},
    "66": {"raise": 0.0,  "call": 0.5},
    "55": {"raise": 0.0,  "call": 0.5},   # partial calls vs a wide open if comfortable
    "44": {"raise": 0.0,  "call": 1/3},
    "33": {"raise": 0.0,  "call": 1/3},
    "22": {"raise": 0.0,  "call": 1/3},

    # =====================
    # Suited Aces
    # =====================
    "AKs": {"raise": 1.0,  "call": 0.0},   # pure 3‑bet for value
    "AQs": {"raise": 1.0,  "call": 0.0},   
    "AJs": {"raise": 0.5,  "call": 0.5},   # can mix 3‑bet or flat vs wide open
    "ATs": {"raise": 1/3, "call": 1/3},  
    "A9s": {"raise": 0.0,  "call": 0.5},  # more playable vs LP than vs EP
    "A8s": {"raise": 0.0,  "call": 0.5},
    "A7s": {"raise": 0.0,  "call": 1/3},
    "A6s": {"raise": 0.0,  "call": 1/3},
    "A5s": {"raise": 1/3, "call": 0.0},  # partial bluff + partial call
    "A4s": {"raise": 1/3, "call": 0.0},
    "A3s": {"raise": 1/3, "call": 0.0},
    "A2s": {"raise": 1/3, "call": 0.0},

    # =====================
    # Offsuit Aces
    # =====================
    "AKo": {"raise": 1.0,  "call": 0.0},   # pure value 3‑bet
    "AQo": {"raise": 1.0, "call": 0.0},  
    "AJo": {"raise": 0.0, "call": 1.0}, 
    "ATo": {"raise": 0.0,  "call": 0.5},  
    "A9o": {"raise": 0.0,  "call": 0.0},   
    "A8o": {"raise": 0.0,  "call": 0.0},

    # =====================
    # Suited Broadways
    # =====================
    "KQs": {"raise": 1.0,  "call": 0.0},  
    "KJs": {"raise": 0.0, "call": 1.0},  
    "KTs": {"raise": 0.0, "call": 1.0},
    "K9s": {"raise": 0.0,  "call": 0.5},  
    "K8s": {"raise": 0.0,  "call": 0.0},

    # =====================
    # Offsuit Kings
    # =====================
    "KQo": {"raise": 1.0, "call": 0.0},  
    "KJo": {"raise": 0.0, "call": 0.5},
    "KTo": {"raise": 0.0,  "call": 0.0},  
    "K9o": {"raise": 0.0,  "call": 0.0},

    # =====================
    # Other Suited Queens
    # =====================
    "QJs": {"raise": 0.5, "call": 0.5},  
    "QTs": {"raise": 0.0, "call": 0.5},
    "Q9s": {"raise": 0.0,  "call": 0.0},   

    # =====================
    # Offsuit Queens
    # =====================
    "QJo": {"raise": 0.0,  "call": 0.0},  
    "QTo": {"raise": 0.0,  "call": 0.0},

    # =====================
    # Suited Jacks
    # =====================
    "JTs": {"raise": 0.5, "call": 0.5},  
    "J9s": {"raise": 0.0,  "call": 0.5},   
    "J8s": {"raise": 0.0,  "call": 0.0},

    # =====================
    # Offsuit Jacks
    # =====================
    "JTo": {"raise": 0.0,  "call": 1/3},  
    "J9o": {"raise": 0.0,  "call": 0.0},

    # =====================
    # Suited Connectors
    # =====================
    "T9s": {"raise": 0.5, "call": 0.5},  
    "T8s": {"raise": 0.0,  "call": 0.5},
    "T7s": {"raise": 0.0,  "call": 0.0},
    "T6s": {"raise": 0.0,  "call": 0.0},

    "98s": {"raise": 0.5,  "call": 0.5},
    "97s": {"raise": 0.0,  "call": 0.5},
    "96s": {"raise": 0.0,  "call": 0.0},

    "87s": {"raise": 0.5,  "call": 0.5},
    "86s": {"raise": 0.0,  "call": 0.0},

    "76s": {"raise": 0.0,  "call": 0.5},
    "75s": {"raise": 0.0,  "call": 0.0},

    "65s": {"raise": 0.0,  "call": 0.5},
    "54s": {"raise": 0.0,  "call": 0.0},

    # =====================
    # Suited Wheel Connectors
    # =====================
    "43s": {"raise": 0.0,  "call": 0.0},
    "32s": {"raise": 0.0,  "call": 0.0}
}


# Visualize the range
open_response_loose = range_construction.generate_range(open_response_range_loose, '../ranges/bb_ranges/bb_open_response_loose')
open_response_distribution_loose = range_construction.range_hand_distribution(open_response_range_loose)
open_response_percent_by_actions_loose = range_construction.range_percent_by_all_actions(open_response_range_loose)
open_response_mean_hand_rank_loose = range_construction.average_range_rank(open_response_range_loose)

print(open_response_percent_by_actions_loose)
print(f'Mean hand rank: {open_response_mean_hand_rank_loose}')
print(f'Percent A or K high: {range_construction.percent_range_high_card(open_response_range_loose)} %')

open_response_distribution_loose[1].to_csv('../ranges/bb_ranges/bb_open_response_distribution_loose.csv')
open_response_distribution_loose[0]
# Out:
# {'raise': {'percent': 7.817998994469584, 'combos': 103.66666666666669}, 'call': {'percent': 7.013574660633484, 'combos': 93.0}, 'fold': {'percent': 85.16842634489693, 'combos': 1129.3333333333333}, 'overall': {'percent': 14.831573655103067, 'combos': 196.66666666666669}}
# Mean hand rank: 17.547619047619047
# Percent A or K high: 57.288135593220346 %
# Defended Flatting range: 12.311827956989246 %
# count     47.000000
# mean      34.276596
# std       31.027829
# min        1.000000
# 25%       12.500000
# 50%       24.000000
# 75%       44.500000
# max      127.000000
# Name: Rank, dtype: float64

# %% [markdown]
# # 4! response range

# %% [markdown]
# Given the slightly earlier position, will consider 5bets only in the case of multiple opponents calling the 4bet. If heads up, then will proceed with only calls.

# %%
response_4bet_range = {
    # Pairs
    "AA": {"raise": 1.0, "call": 0.0},
    "KK": {"raise": 1.0, "call": 0.0},
    "QQ": {"raise": 1.0, "call": 0.0},
    "JJ": {"raise": 0, "call": 1.0},
    "TT": {"raise": 0, "call": 1.0},
    "99": {"raise": 0, "call": 0.0},
    "88": {"raise": 0, "call": 0.0},

    "AKs": {"raise": 0, "call": 1.0},
    "AQs": {"raise": 0, "call": 0.0},
    "AJs": {"raise": 0, "call": 0.0},
    "ATs": {"raise": 0, "call": 0.0},

    "AKo": {"raise": 0.0, "call": 1.0},
    "AQo": {"raise": 0.0, "call": 0.0},
    "AJo": {"raise": 0.0, "call": 0.0},
    "ATo": {"raise": 0.0, "call": 0.0},

    "KQs": {"raise": 0.0, "call": 0.0},
    "KJs": {"raise": 0.0, "call": 0.0},

    "KQo": {"raise": 0.0, "call": 0.0},

    "QJs": {"raise": 0.0, "call": 0.0},
    "JTs": {"raise": 0.0, "call": 0.0},
}

response_4bet = range_construction.generate_range(response_4bet_range, '../ranges/bb_ranges/bb_4!response')
response_4bet_distribution = range_construction.range_hand_distribution(response_4bet_range)
response_4bet_percent_by_actions = range_construction.range_percent_by_all_actions(response_4bet_range)
response_4bet_mean_hand_rank = range_construction.average_range_rank(response_4bet_range)

print(response_4bet_percent_by_actions)
print(f'Mean hand rank: {response_4bet_mean_hand_rank}')
print(f'Percent A or K high: {range_construction.percent_range_high_card(response_4bet_range)} %')


defended_3bet = 100*(response_4bet_percent_by_actions['overall']['combos'] / open_response_percent_by_actions_loose['raise']['combos'])
print(f'3bet defended {defended_3bet}')

response_4bet_distribution[1].to_csv('../ranges/bb_ranges/bb_response_4bet_distribution.csv')
response_4bet_distribution[0]
# Out:
# {'raise': {'percent': 1.3574660633484164, 'combos': 18.0}, 'call': {'percent': 2.1116138763197587, 'combos': 28.0}, 'fold': {'percent': 96.53092006033182, 'combos': 1280.0}, 'overall': {'percent': 3.469079939668175, 'combos': 46.0}}
# Mean hand rank: 5.0
# Percent A or K high: 60.86956521739131 %
# 3bet defended 44.37299035369774
# count     7.000000
# mean      5.000000
# std       3.829708
# min       1.000000
# 25%       2.500000
# 50%       4.000000
# 75%       6.500000
# max      12.000000
# Name: Rank, dtype: float64
