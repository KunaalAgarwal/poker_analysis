# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
import importlib
import range_construction
# Out:
# <module 'range_construction' from 'c:\\Users\\kuna8\\personal_projects\\poker_cash_ranges\\range_construction.py'>

# %%
importlib.reload(range_construction)
hand_actions = {
    "AA": {"raise": 1.0, "call": 0.0, "fold": 0.0},
    "AKs": {"raise": 1.0, "call": 0.0, "fold": 0.0},
    "AQs": {"raise": 0.75, "call": 0.25, "fold": 0.0},
    "AJs": {"raise": 0.5, "call": 0.5, "fold": 0.0},
    "ATs": {"raise": 0.5, "call": 0.0, "fold": 0.0},
}

# Visualize the range
range_construction.generate_range(hand_actions)
print(range_construction.range_percent_overall(hand_actions))
# Out:
# 1.6591251885369533
