# %%
import importlib
import range_construction
importlib.reload(range_construction)
# Out:
# <module 'range_construction' from 'c:\\Users\\kuna8\\personal_projects\\poker_cash_ranges\\src\\range_construction.py'>

# %% [markdown]
# ## VPIP goal = ~45% sum(RFI, 3!, Flat)

# %% [markdown]
# ## RFI (Raise first in, Open) range

# %%
rfi_range = {
    # Pairs
    "AA": {"raise": 1.0, "call": 0.0},
    "KK": {"raise": 1.0, "call": 0.0},
    "QQ": {"raise": 1.0, "call": 0.0},
    "JJ": {"raise": 1.0, "call": 0.0},
    "TT": {"raise": 1.0, "call": 0.0},
    "99": {"raise": 1.0, "call": 0.0},
    "77": {"raise": 1.0, "call": 0.0},
    "88": {"raise": 1.0, "call": 0.0},
    "66": {"raise": 1.0, "call": 0.0},
    "55": {"raise": 0.5, "call": 0.0},
    "44": {"raise": 0.5, "call": 0.0},
    "33": {"raise": 0.5, "call": 0.0},
    "22": {"raise": 0.5, "call": 0.0},

    "AKs": {"raise": 1.0, "call": 0.0},
    "AQs": {"raise": 1.0, "call": 0.0},
    "AJs": {"raise": 1.0, "call": 0.0},
    "ATs": {"raise": 1.0, "call": 0.0},
    "A9s": {"raise": 1.0, "call": 0.0},
    "A8s": {"raise": 1.0, "call": 0.0},
    "A7s": {"raise": 1.0, "call": 0.0},
    "A6s": {"raise": 1.0, "call": 0.0},
    "A5s": {"raise": 1.0, "call": 0.0},
    "A4s": {"raise": 1.0, "call": 0.0},
    "A3s": {"raise": 1.0, "call": 0.0},
    "A2s": {"raise": 1.0, "call": 0.0},

    "AKo": {"raise": 1.0, "call": 0.0},
    "AQo": {"raise": 1.0, "call": 0.0},
    "AJo": {"raise": 1.0, "call": 0.0},
    "ATo": {"raise": 1.0, "call": 0.0},
    "A9o": {"raise": 1.0, "call": 0.0},
    "A8o": {"raise": 1.0, "call": 0.0},
    "A7o": {"raise": 0.5, "call": 0.0},
    "A6o": {"raise": 0.5, "call": 0.0},
    "A5o": {"raise": 1/3, "call": 0.0},
    "A4o": {"raise": 1/3, "call": 0.0},
    "A3o": {"raise": 1/3, "call": 0.0},
    "A2o": {"raise": 1/3, "call": 0.0},

    "KQs": {"raise": 1.0, "call": 0.0},
    "KJs": {"raise": 1.0, "call": 0.0},
    "KTs": {"raise": 1.0, "call": 0.0},
    "K9s": {"raise": 1.0, "call": 0.0},
    "K8s": {"raise": 1.0, "call": 0.0},
    "K7s": {"raise": 0.5, "call": 0.0},
    "K6s": {"raise": 0.5, "call": 0.0},

    "KQo": {"raise": 1.0, "call": 0.0},
    "KJo": {"raise": 1.0, "call": 0.0},
    "KTo": {"raise": 1.0, "call": 0.0},
    "K9o": {"raise": 1.0, "call": 0.0},
    "K8o": {"raise": 1.0, "call": 0.0},
    "K7o": {"raise": 0.5, "call": 0.0},

    "QJs": {"raise": 1.0, "call": 0.0},
    "QTs": {"raise": 1.0, "call": 0.0},
    "Q9s": {"raise": 1.0, "call": 0.0},
    "Q8s": {"raise": 0.5, "call": 0.0},
    
    "QJo": {"raise": 1.0, "call": 0.0},
    "QTo": {"raise": 1.0, "call": 0.0},
    "Q9o": {"raise": 1.0, "call": 0.0},
    "Q8o": {"raise": 0.5, "call": 0.0},

    "JTs": {"raise": 1.0, "call": 0.0},
    "J9s": {"raise": 1.0, "call": 0.0},
    "J8s": {"raise": 0.5, "call": 0.0},

    "JTo": {"raise": 1.0, "call": 0.0},
    "J9o": {"raise": 0.5, "call": 0.0},

    "T9s": {"raise": 1.0, "call": 0.0},
    "T8s": {"raise": 1.0, "call": 0.0},   

    "98s": {"raise": 1.0, "call": 0.0},
    "97s": {"raise": 1.0, "call": 0.0},

    "87s": {"raise": 1.0, "call": 0.0},
    "86s": {"raise": 0.0, "call": 0.0},

    "76s": {"raise": 1.0, "call": 0.0},
    "75s": {"raise": 0.0, "call": 0.0},

    "65s": {"raise": 0.5, "call": 0.0},
    
    "54s": {"raise": 0.5, "call": 0.0},

    "43s": {"raise": 0.0, "call": 0.0},

    "32s": {"raise": 0.0, "call": 0.0},
}

# Visualize the range
rfi = range_construction.generate_range(rfi_range, '../ranges/co_ranges/co_rfi.png')
rfi_distribution = range_construction.range_hand_distribution(rfi_range)
rfi_percent_by_actions = range_construction.range_percent_by_all_actions(rfi_range)
rfi_mean_hand_rank = range_construction.average_range_rank(rfi_range)


print(rfi_percent_by_actions)
print(f'Mean hand rank: {rfi_mean_hand_rank}')
print(f'Percent A or K high: {range_construction.percent_range_high_card(rfi_range)} %')

rfi_distribution[1].to_csv('../ranges/co_ranges/co_rfi_distribution.csv')
rfi_distribution[0]
# Out:
# {'raise': {'percent': 31.372549019607842, 'combos': 416.0}, 'call': {'percent': 0.0, 'combos': 0}, 'fold': {'percent': 68.62745098039215, 'combos': 910.0}, 'overall': {'percent': 31.372549019607842, 'combos': 416.0}}
# Mean hand rank: 31.399061032863845
# Percent A or K high: 60.09615384615385 %
# count     71.000000
# mean      40.112676
# std       29.196648
# min        1.000000
# 25%       18.500000
# 50%       36.000000
# 75%       54.000000
# max      138.000000
# Name: Rank, dtype: float64

# %% [markdown]
# ## 3! Response range

# %%
response_3bet_range = { # Assuming btn 3bet here
    # Pairs
    "AA": {"raise": 1.0, "call": 0.0}, 
    "KK": {"raise": 1.0, "call": 0.0}, 
    "QQ": {"raise": 1.0, "call": 0.0},
    "JJ": {"raise": 1.0, "call": 0.0}, 
    "TT": {"raise": 1.0, "call": 0.0}, 

    "99": {"raise": 0.5, "call": 0.5}, 
    "88": {"raise": 0.0, "call": 1.0},  
    "77": {"raise": 0.0, "call": 0.5},
    "66": {"raise": 0.5, "call": 0.0}, 
    "55": {"raise": 0.0, "call": 0.0},
    # 4bet bluff (unblocks AK, AQ, AJ, KQ, etc.), while ahead of those hands and can put high pressure on middling pairs
    "44": {"raise": 0.17, "call": 0.0}, 
    "33": {"raise": 0.17, "call": 0.0},  
    "22": {"raise": 0.17, "call": 0.0}, 

    "AKs": {"raise": 1.0, "call": 0.0},
    "AQs": {"raise": 0.5, "call": 0.5}, 
    "AJs": {"raise": 0.5, "call": 0.5},
    "ATs": {"raise": 1/3, "call": 2/3},
    "A9s": {"raise": 0.0, "call": 0.5},
    "A8s": {"raise": 0.0, "call": 0.0},
    "A7s": {"raise": 0.0, "call": 0.0},
    "A6s": {"raise": 0.0, "call": 0.0},
    # 4bet bluffs
    "A5s": {"raise": 1.0, "call": 0.0}, 
    "A4s": {"raise": 1.0, "call": 0.0},
    "A3s": {"raise": 1/3, "call": 0.0},
    "A2s": {"raise": 1/3, "call": 0.0},

    "AKo": {"raise": 0.75, "call": 0.25},
    "AQo": {"raise": 1/3, "call": 2/3},
    "AJo": {"raise": 0.0, "call": 1.0},
    "ATo": {"raise": 0.0, "call": 0.5}, 
    "A9o": {"raise": 0.0, "call": 0.0},
    "A5o": {"raise": 0.0, "call": 0.0},
    "A4o": {"raise": 0.0, "call": 0.0},
    "A3o": {"raise": 0.0, "call": 0.0},
    "A2o": {"raise": 0.0, "call": 0.0},

    "KQs": {"raise": 0.5, "call": 0.5},
    "KJs": {"raise": 0.0, "call": 1.0},
    "KTs": {"raise": 0.0, "call": 0.5},
    "K9s": {"raise": 0.0, "call": 0.0},

    "KQo": {"raise": 0.0, "call": 1.0},
    "KJo": {"raise": 0.0, "call": 0.25},
    "KTo": {"raise": 0.0, "call": 0.0},

    "QJs": {"raise": 0.0, "call": 1.0},
    "QTs": {"raise": 0.0, "call": 0.5},

    "QJo": {"raise": 0.0, "call": 0.0},
    "QTo": {"raise": 0.0, "call": 0.0},
    "Q9o": {"raise": 0.0, "call": 0.0},

    "JTs": {"raise": 0.5, "call": 0.5},
    "J9s": {"raise": 0.0, "call": 0.0},

    "JTo": {"raise": 0.0, "call": 0.0},
    "J9o": {"raise": 0.0, "call": 0.0},

    "T9s": {"raise": 0.5, "call": 0.5},
    "T8s": {"raise": 0.0, "call": 0.0},

    "98s": {"raise": 0.0, "call": 1.0},
    "97s": {"raise": 0.0, "call": 0.0},

    "87s": {"raise": 0.0, "call": 0.5},
    "86s": {"raise": 0.0, "call": 0.0},

    "76s": {"raise": 0.0, "call": 1/3},
    "75s": {"raise": 0.0, "call": 0.0},

    "65s": {"raise": 0.0, "call": 0.0},
}
# Visualize the range
response_3bet = range_construction.generate_range(response_3bet_range, '../ranges/co_ranges/co_3!response.png')
response_3bet_distribution = range_construction.range_hand_distribution(response_3bet_range)
response_3bet_percent_by_actions = range_construction.range_percent_by_all_actions(response_3bet_range)
response_3bet_mean_hand_rank = range_construction.average_range_rank(response_3bet_range)

defended_rfi = 100*response_3bet_percent_by_actions['overall']['combos'] / rfi_percent_by_actions['overall']['combos'] 

print(response_3bet_percent_by_actions)
print(f'Mean hand rank: {response_3bet_mean_hand_rank}')
print(f'Percent A or K high: {range_construction.percent_range_high_card(response_3bet_range)} %')
print(f'Percent of CO RFI defended: {defended_rfi} %')

response_3bet_distribution[1].to_csv('../ranges/co_ranges/co_3bet_response_distribution.csv')
response_3bet_distribution[0]
# Out:
# {'raise': {'percent': 5.8868778280543, 'combos': 78.06000000000002}, 'call': {'percent': 6.787330316742081, 'combos': 90.0}, 'fold': {'percent': 87.32579185520362, 'combos': 1157.94}, 'overall': {'percent': 12.674208144796381, 'combos': 168.06}}
# Mean hand rank: 14.375507246376813
# Percent A or K high: 64.06442143678845 %
# Percent of CO RFI defended: 40.39903846153846 %
# count     37.000000
# mean      29.081081
# std       28.132009
# min        1.000000
# 25%       10.000000
# 50%       19.000000
# 75%       39.000000
# max      115.000000
# Name: Rank, dtype: float64

# %% [markdown]
# # Open response range

# %%
open_response_range = {
    # Pairs
    "AA": {"raise": 1.0, "call": 0.0},
    "KK": {"raise": 1.0, "call": 0.0},
    "QQ": {"raise": 1.0, "call": 0.0},
    "JJ": {"raise": 1.0, "call": 0.0},
    "TT": {"raise": 1.0, "call": 0.0},
    "99": {"raise": 1.0, "call": 0.0},
    "88": {"raise": 1/3, "call": 2/3},
    "77": {"raise": 0.0, "call": 0.75}, 
    # Want to minimize set mining
    "66": {"raise": 0.25, "call": 0.25},
    "55": {"raise": 1/6, "call": 1/6}, 
    "44": {"raise": 0.0, "call": 1/6},
    "33": {"raise": 0.0, "call": 1/6},
    "22": {"raise": 0.0, "call": 1/6},

    "AKs": {"raise": 1.0, "call": 0.0},
    "AQs": {"raise": 1.0, "call": 0.0},
    "AJs": {"raise": 1.0, "call": 0.0},
    "ATs": {"raise": 0.5, "call": 0.5},
    "A9s": {"raise": 0.0, "call": 1.0},
    "A8s": {"raise": 0.0, "call": 0.5},
    "A7s": {"raise": 0.0, "call": 0.0},
    "A6s": {"raise": 0.0, "call": 0.0},
    # Can use more 3bet bluffs depending on how wide the opener is.
    "A5s": {"raise": 0.5, "call": 0.0}, 
    "A4s": {"raise": 0.5, "call": 0.0},
    "A3s": {"raise": 0.0, "call": 0.0},
    "A2s": {"raise": 0.0, "call": 0.0}, 

    "AKo": {"raise": 0.75, "call": 0.25}, # keep some combos to uncap the flatting range
    "AQo": {"raise": 1.0, "call": 0.0},
    "AJo": {"raise": 0.75, "call": 0.25},
    "ATo": {"raise": 0.0, "call": 1.0},
    "A9o": {"raise": 0.0, "call": 0.0},
    "A8o": {"raise": 0.0, "call": 0.0},

    "KQs": {"raise": 1.0, "call": 0.0},
    "KJs": {"raise": 0.5, "call": 0.5},
    "KTs": {"raise": 0.0, "call": 0.25},
    "K9s": {"raise": 0.0, "call": 0.0},
    "K8s": {"raise": 0.0, "call": 0.0},

    "KQo": {"raise": 0.25, "call": 0.75},
    "KJo": {"raise": 0.0, "call": 0.25},
    "KTo": {"raise": 0.0, "call": 0.0},
    "K9o": {"raise": 0.0, "call": 0.0},

    "QJs": {"raise": 0.0, "call": 1.0}, # depends how wide opener is
    "QTs": {"raise": 0.0, "call": 0.25},
    "Q9s": {"raise": 0.0, "call": 0.25},
    
    "QJo": {"raise": 0.0, "call": 0.0},
    "QTo": {"raise": 0.0, "call": 0.0},

    "JTs": {"raise": 0.5, "call": 0.5},
    "J9s": {"raise": 0.0, "call": 0.0}, 

    "JTo": {"raise": 0.0, "call": 0.0},
    "J9o": {"raise": 0.0, "call": 0.0},

    "T9s": {"raise": 0.5, "call": 0.5},
    "T8s": {"raise": 0.0, "call": 0.0},

    "98s": {"raise": 0.0, "call": 1.0}, 
    "97s": {"raise": 0.0, "call": 0.0},

    "87s": {"raise": 0.0, "call": 1.0}, 
    "86s": {"raise": 0.0, "call": 0.0},

    "76s": {"raise": 0.0, "call": 0.5},
    "75s": {"raise": 0.0, "call": 0.0},

    "65s": {"raise": 0.0, "call": 0.0}, 
    
    "54s": {"raise": 0.0, "call": 0.0},

    "43s": {"raise": 0.0, "call": 0.0},

    "32s": {"raise": 0.0, "call": 0.0},
}

# Visualize the range
open_response = range_construction.generate_range(open_response_range, '../ranges/co_ranges/co_open_response')
open_response_distribution = range_construction.range_hand_distribution(open_response_range)
open_response_percent_by_actions = range_construction.range_percent_by_all_actions(open_response_range)
open_response_mean_hand_rank = range_construction.average_range_rank(open_response_range)

print(open_response_percent_by_actions)
print(f'Mean hand rank: {open_response_mean_hand_rank}')
print(f'Percent A or K high: {range_construction.percent_range_high_card(open_response_range)} %')
print(f'Defended Flatting range: {range_construction.flat_defense(response_3bet_range, open_response_range)} %')

open_response_distribution[1].to_csv('../ranges/co_ranges/co_open_response_distribution.csv')
open_response_distribution[0]
# Out:
# {'raise': {'percent': 7.6546003016591255, 'combos': 101.5}, 'call': {'percent': 5.656108597285068, 'combos': 75.0}, 'fold': {'percent': 86.6892911010558, 'combos': 1149.5}, 'overall': {'percent': 13.310708898944194, 'combos': 176.5}}
# Mean hand rank: 14.699652777777777
# Percent A or K high: 62.3229461756374 %
# Defended Flatting range: 67.90222222222222 %
# count     38.000000
# mean      28.368421
# std       27.629226
# min        1.000000
# 25%       10.250000
# 50%       19.500000
# 75%       34.750000
# max      115.000000
# Name: Rank, dtype: float64

# %% [markdown]
# # 4! response range

# %%
response_4bet_range = {
    # Pairs
    "AA": {"raise": 1.0, "call": 0.0},
    "KK": {"raise": 1.0, "call": 0.0},
    "QQ": {"raise": 1/3, "call": 2/3},
    "JJ": {"raise": 0, "call": 1.0},
    "TT": {"raise": 0, "call": 1.0},
    "99": {"raise": 0, "call": 0.0},
    "88": {"raise": 0, "call": 0.0},

    "AKs": {"raise": 0, "call": 1.0},
    "AQs": {"raise": 0, "call": 0.5},
    "AJs": {"raise": 0, "call": 0.0},
    "ATs": {"raise": 0, "call": 0.0},

    "AKo": {"raise": 0.0, "call": 1.0},
    "AQo": {"raise": 0.0, "call": 0.0},
    "AJo": {"raise": 0.0, "call": 0.0},
    "ATo": {"raise": 0.0, "call": 0.0},

    "KQs": {"raise": 0.0, "call": 0.5},
    "KJs": {"raise": 0.0, "call": 0.0},

    "KQo": {"raise": 0.0, "call": 0.0},

    "QJs": {"raise": 0.0, "call": 0.0},
    "JTs": {"raise": 0.0, "call": 0.0},
}

response_4bet = range_construction.generate_range(response_4bet_range, '../ranges/co_ranges/co_4!response')
response_4bet_distribution = range_construction.range_hand_distribution(response_4bet_range)
response_4bet_percent_by_actions = range_construction.range_percent_by_all_actions(response_4bet_range)
response_4bet_mean_hand_rank = range_construction.average_range_rank(response_4bet_range)

defended_3bet = 100*(response_4bet_percent_by_actions['overall']['combos'] / open_response_percent_by_actions['raise']['combos'])

print(response_4bet_percent_by_actions)
print(f'Mean hand rank: {response_4bet_mean_hand_rank}')
print(f'Percent A or K high: {range_construction.percent_range_high_card(response_4bet_range)} %')
print(f'3bet defended: {defended_3bet} %')

response_4bet_distribution[1].to_csv('../ranges/co_ranges/co_response_4bet_distribution.csv')
response_4bet_distribution[0]
# Out:
# {'raise': {'percent': 1.0558069381598794, 'combos': 14.0}, 'call': {'percent': 2.7149321266968327, 'combos': 36.0}, 'fold': {'percent': 96.22926093514329, 'combos': 1276.0}, 'overall': {'percent': 3.770739064856712, 'combos': 50.0}}
# Mean hand rank: 4.8
# Percent A or K high: 64.0 %
# 3bet defended: 49.26108374384236 %
# count     9.000000
# mean      6.777778
# std       5.068969
# min       1.000000
# 25%       3.000000
# 50%       5.000000
# 75%      10.000000
# max      16.000000
# Name: Rank, dtype: float64
