# %%
import importlib
import range_construction
importlib.reload(range_construction)
# Out:
# <module 'range_construction' from 'c:\\Users\\kuna8\\personal_projects\\poker_cash_ranges\\src\\range_construction.py'>

# %% [markdown]
# ## VPIP goal = ~30% sum(RFI, 3!, Flat)

# %% [markdown]
# ## RFI (Raise first in, Open) range

# %%
rfi_range = {
    # Pairs
    "AA": {"raise": 1.0, "call": 0.0},
    "KK": {"raise": 1.0, "call": 0.0},
    "QQ": {"raise": 1.0, "call": 0.0},
    "JJ": {"raise": 1.0, "call": 0.0},
    "TT": {"raise": 1.0, "call": 0.0},
    "99": {"raise": 1.0, "call": 0.0},
    "77": {"raise": 1.0, "call": 0.0},
    "88": {"raise": 1.0, "call": 0.0},
    "66": {"raise": 0.5, "call": 0.0},
    "55": {"raise": 0.5, "call": 0.0},
    "44": {"raise": 0.5, "call": 0.0},
    "33": {"raise": 0.0, "call": 0.0},
    "22": {"raise": 0.0, "call": 0.0},

    "AKs": {"raise": 1.0, "call": 0.0},
    "AQs": {"raise": 1.0, "call": 0.0},
    "AJs": {"raise": 1.0, "call": 0.0},
    "ATs": {"raise": 1.0, "call": 0.0},
    "A9s": {"raise": 1.0, "call": 0.0},
    "A8s": {"raise": 0.5, "call": 0.0},
    "A7s": {"raise": 0.5, "call": 0.0}, # fold if too much 3bet
    "A6s": {"raise": 0.5, "call": 0.0}, # fold if too much 3bet
    "A5s": {"raise": 1.0, "call": 0.0},
    "A4s": {"raise": 0.5, "call": 0.0},
    "A3s": {"raise": 0.5, "call": 0.0},
    "A2s": {"raise": 0.5, "call": 0.0},

    "AKo": {"raise": 1.0, "call": 0.0},
    "AQo": {"raise": 1.0, "call": 0.0},
    "AJo": {"raise": 1.0, "call": 0.0},
    "ATo": {"raise": 1.0, "call": 0.0}, 
    "A9o": {"raise": 0.75, "call": 0.0},
    "A8o": {"raise": 0.5, "call": 0.0}, # fold if too much 3bet
    "A7o": {"raise": 0.5, "call": 0.0}, # fold if too much 3bet
    "A6o": {"raise": 0.0, "call": 0.0},
    "A5o": {"raise": 0.0, "call": 0.0},
    "A4o": {"raise": 0.0, "call": 0.0},
    "A3o": {"raise": 0.0, "call": 0.0},
    "A2o": {"raise": 0.0, "call": 0.0},

    "KQs": {"raise": 1.0, "call": 0.0},
    "KJs": {"raise": 1.0, "call": 0.0},
    "KTs": {"raise": 1.0, "call": 0.0},
    "K9s": {"raise": 0.5, "call": 0.0},
    "K8s": {"raise": 0.0, "call": 0.0},
    "K7s": {"raise": 0.0, "call": 0.0},
    "K6s": {"raise": 0.0, "call": 0.0},

    "KQo": {"raise": 1.0, "call": 0.0},
    "KJo": {"raise": 1.0, "call": 0.0}, # fold if too much 3bet
    "KTo": {"raise": 0.5, "call": 0.0}, # fold if too much 3bet
    "K9o": {"raise": 0.0, "call": 0.0},
    "K8o": {"raise": 0.0, "call": 0.0},
    "K7o": {"raise": 0.0, "call": 0.0},

    "QJs": {"raise": 1.0, "call": 0.0},
    "QTs": {"raise": 1.0, "call": 0.0},
    "Q9s": {"raise": 0.5, "call": 0.0},
    "Q8s": {"raise": 0.0, "call": 0.0},
    
    "QJo": {"raise": 0.5, "call": 0.0},
    "QTo": {"raise": 0.0, "call": 0.0},
    "Q9o": {"raise": 0.0, "call": 0.0},

    "JTs": {"raise": 1.0, "call": 0.0},
    "J9s": {"raise": 0.5, "call": 0.0},

    "JTo": {"raise": 0.5, "call": 0.0}, # fold if too much 3bet
    "J9o": {"raise": 0.0, "call": 0.0},

    "T9s": {"raise": 1.0, "call": 0.0},
    "T8s": {"raise": 0.0, "call": 0.0},   

    "98s": {"raise": 1.0, "call": 0.0},
    "97s": {"raise": 0.0, "call": 0.0},

    "87s": {"raise": 1.0, "call": 0.0},
    "86s": {"raise": 0.0, "call": 0.0},

    "76s": {"raise": 0.5, "call": 0.0},
    "75s": {"raise": 0.0, "call": 0.0},

    "65s": {"raise": 0.5, "call": 0.0},
    
    "54s": {"raise": 0.0, "call": 0.0},

    "43s": {"raise": 0.0, "call": 0.0},

    "32s": {"raise": 0.0, "call": 0.0},
}

# Visualize the range
rfi = range_construction.generate_range(rfi_range, '../ranges/hj_ranges/hj_rfi.png')
rfi_distribution = range_construction.range_hand_distribution(rfi_range)
rfi_percent_by_actions = range_construction.range_percent_by_all_actions(rfi_range)
rfi_mean_hand_rank = range_construction.average_range_rank(rfi_range)


print(rfi_percent_by_actions)
print(f'Mean hand rank: {rfi_mean_hand_rank}')
print(f'Percent A or K high: {range_construction.percent_range_high_card(rfi_range)} %')

rfi_distribution[1].to_csv('../ranges/hj_ranges/hj_rfi_distribution.csv')
rfi_distribution[0]
# Out:
# {'raise': {'percent': 18.85369532428356, 'combos': 250.0}, 'call': {'percent': 0.0, 'combos': 0}, 'fold': {'percent': 81.14630467571644, 'combos': 1076.0}, 'overall': {'percent': 18.85369532428356, 'combos': 250.0}}
# Mean hand rank: 22.0765306122449
# Percent A or K high: 64.4 %
# count     49.000000
# mean      30.775510
# std       27.369589
# min        1.000000
# 25%       13.000000
# 50%       25.000000
# 75%       37.000000
# max      127.000000
# Name: Rank, dtype: float64

# %% [markdown]
# ## 3! Response range

# %%
response_3bet_range = {
    # Pairs
    "AA": {"raise": 1.0, "call": 0.0}, 
    "KK": {"raise": 1.0, "call": 0.0}, 
    "QQ": {"raise": 1.0, "call": 0.0},
    "JJ": {"raise": 1.0, "call": 0.0}, 
    "TT": {"raise": 1.0, "call": 0.0}, 
    "99": {"raise": 0.5, "call": 0.5}, 
    "88": {"raise": 0.0, "call": 1.0},  
    "77": {"raise": 0.0, "call": 0.5},
    # 4bet bluff (unblocks AK, AQ, AJ, KQ, etc.), while ahead of those hands and can put high pressure on middling pairs
    "66": {"raise": 0.5, "call": 0.0}, 
    "55": {"raise": 0.0, "call": 0.0},
    "44": {"raise": 0.0, "call": 0.0}, 
    "33": {"raise": 0.0, "call": 0.0},  
    "22": {"raise": 0.0, "call": 0.0}, 

    "AKs": {"raise": 1.0, "call": 0.0},
    "AQs": {"raise": 0.5, "call": 0.5}, 
    "AJs": {"raise": 0.0, "call": 1.0},
    "ATs": {"raise": 0.0, "call": 0.5},
    "A9s": {"raise": 0.0, "call": 0.0},
    "A8s": {"raise": 0.0, "call": 0.0},
    "A7s": {"raise": 0.0, "call": 0.0},
    "A6s": {"raise": 0.0, "call": 0.0},
    # 4bet bluff
    "A5s": {"raise": 1.0, "call": 0.0}, 
    "A4s": {"raise": 0.5, "call": 0.0},
    "A3s": {"raise": 0.25, "call": 0.0},
    "A2s": {"raise": 0.25, "call": 0.0}, 

    "AKo": {"raise": 0.75, "call": 0.25}, # uncap flatting range
    "AQo": {"raise": 0.0, "call": 1.0}, 
    "AJo": {"raise": 0.0, "call": 1.0},
    "ATo": {"raise": 0.0, "call": 0.0}, 
    "A9o": {"raise": 0.0, "call": 0.0},

    "A5o": {"raise": 0.0, "call": 0.0},
    "A4o": {"raise": 0.0, "call": 0.0},
    "A3o": {"raise": 0.0, "call": 0.0},
    "A2o": {"raise": 0.0, "call": 0.0},

    "KQs": {"raise": 0.25, "call": 0.75},
    "KJs": {"raise": 0.0, "call": 0.5},
    "KTs": {"raise": 0.0, "call": 0.0},
    "K9s": {"raise": 0.0, "call": 0.0},

    "KQo": {"raise": 0.0, "call": 1.0},
    "KJo": {"raise": 0.0, "call": 0.0},
    "KTo": {"raise": 0.0, "call": 0.0},

    "QJs": {"raise": 0.0, "call": 1.0},
    "QTs": {"raise": 0.0, "call": 0.0},

    "QJo": {"raise": 0.0, "call": 0.0},
    "QTo": {"raise": 0.0, "call": 0.0},
    "Q9o": {"raise": 0.0, "call": 0.0},

    "JTs": {"raise": 0.5, "call": 0.5}, # 4bet bluff (unblocks middling pairs that will def fold, good playability if called)
    "J9s": {"raise": 0.0, "call": 0.0},

    "JTo": {"raise": 0.0, "call": 0.0},
    "J9o": {"raise": 0.0, "call": 0.0},

    "T9s": {"raise": 0.5, "call": 0.5}, # 4bet bluff (unblocks middling pairs that will def fold, good playability if called)
    "T8s": {"raise": 0.0, "call": 0.0},   

    "98s": {"raise": 0.0, "call": 0.75},
    "97s": {"raise": 0.0, "call": 0.0},

    "87s": {"raise": 0.0, "call": 0.25},
    "86s": {"raise": 0.0, "call": 0.0},

    "76s": {"raise": 0.0, "call": 0.0},
    "75s": {"raise": 0.0, "call": 0.0},

    "65s": {"raise": 0.0, "call": 0.0},
}
# Visualize the range
response_3bet = range_construction.generate_range(response_3bet_range, '../ranges/hj_ranges/hj_3!response.png')
response_3bet_distribution = range_construction.range_hand_distribution(response_3bet_range)
response_3bet_percent_by_actions = range_construction.range_percent_by_all_actions(response_3bet_range)
response_3bet_mean_hand_rank = range_construction.average_range_rank(response_3bet_range)

defended_rfi = 100*response_3bet_percent_by_actions['overall']['combos'] / rfi_percent_by_actions['overall']['combos'] 

print(response_3bet_percent_by_actions)
print(f'Mean hand rank: {response_3bet_mean_hand_rank}')
print(f'Percent A or K high: {range_construction.percent_range_high_card(response_3bet_range)} %')
print(f'Percent of HJ RFI defended: {defended_rfi} %')

response_3bet_distribution[1].to_csv('../ranges/hj_ranges/hj_3bet_response_distribution.csv')
response_3bet_distribution[0]
# Out:
# {'raise': {'percent': 4.826546003016592, 'combos': 64.0}, 'call': {'percent': 5.731523378582202, 'combos': 76.0}, 'fold': {'percent': 89.44193061840122, 'combos': 1186.0}, 'overall': {'percent': 10.558069381598793, 'combos': 140.0}}
# Mean hand rank: 13.294117647058824
# Percent A or K high: 62.857142857142854 %
# Percent of HJ RFI defended: 56.0 %
# count     28.000000
# mean      23.500000
# std       24.506235
# min        1.000000
# 25%        7.750000
# 50%       14.500000
# 75%       32.000000
# max      100.000000
# Name: Rank, dtype: float64

# %% [markdown]
# # Open response range

# %%
open_response_range = {
    # Pairs
    "AA": {"raise": 1.0, "call": 0.0},
    "KK": {"raise": 1.0, "call": 0.0},
    "QQ": {"raise": 1.0, "call": 0.0},
    "JJ": {"raise": 1.0, "call": 0.0},
    "TT": {"raise": 1.0, "call": 0.0},
    "99": {"raise": 1.0, "call": 0.0},
    "88": {"raise": 0.0, "call": 1.0},
    "77": {"raise": 0.0, "call": 2/3}, 
    "66": {"raise": 0.0, "call": 0.25}, # depends how tight the early position players are
    "55": {"raise": 0.0, "call": 0.0}, 
    "44": {"raise": 0.0, "call": 0.0},
    "33": {"raise": 0.0, "call": 0.0},
    "22": {"raise": 0.0, "call": 0.0},

    "AKs": {"raise": 1.0, "call": 0.0}, 
    "AQs": {"raise": 1.0, "call": 0.0},
    "AJs": {"raise": 1.0, "call": 0.0},
    "ATs": {"raise": 0.5, "call": 0.5},
    "A9s": {"raise": 0.0, "call": 1.0},
    "A8s": {"raise": 0.0, "call": 0.0},
    "A7s": {"raise": 0.0, "call": 0.0},
    "A6s": {"raise": 0.0, "call": 0.0},
    # very solid 3bet bluffs, but don't need to many bluffs against relatively tight opening ranges
    "A5s": {"raise": 0.5, "call": 0.0},
    "A4s": {"raise": 0.25, "call": 0.0},
    "A3s": {"raise": 0.0, "call": 0.0},
    "A2s": {"raise": 0.0, "call": 0.0}, 

    "AKo": {"raise": 0.75, "call": 0.25}, # uncap flatting range, late enough position where we aren't worried about pot going "super multi-way"
    "AQo": {"raise": 1.0, "call": 0.0}, 
    "AJo": {"raise": 0.5, "call": 0.5},  
    "ATo": {"raise": 0.0, "call": 0.75},  
    "A9o": {"raise": 0.0, "call": 0.0}, 
    "A8o": {"raise": 0.0, "call": 0.0}, 

    "KQs": {"raise": 1.0, "call": 0.0},
    "KJs": {"raise": 0.5, "call": 0.5}, # raising as a semi-bluff, pretty good bluff too. 
    "KTs": {"raise": 0.0, "call": 0.0},  
    "K9s": {"raise": 0.0, "call": 0.0},
    "K8s": {"raise": 0.0, "call": 0.0}, 
  
    "KQo": {"raise": 0.25, "call": 0.75}, 
    "KJo": {"raise": 0.0, "call": 0.25}, # depends on position of open
    "KTo": {"raise": 0.0, "call": 0.0}, 
    "K9o": {"raise": 0.0, "call": 0.0}, 

    "QJs": {"raise": 0.0, "call": 0.5},  
    "QTs": {"raise": 0.0, "call": 0.0},  
    "Q9s": {"raise": 0.0, "call": 0.0}, 
     
    "QJo": {"raise": 0.0, "call": 0.0}, 
    "QTo": {"raise": 0.0, "call": 0.0},

    "JTs": {"raise": 0.5, "call": 0.5}, # solid semi-bluff, same reasons as 4bet bluff
    "J9s": {"raise": 0.0, "call": 0.0}, 

    "JTo": {"raise": 0.0, "call": 0.0},
    "J9o": {"raise": 0.0, "call": 0.0},

    "T9s": {"raise": 0.5, "call": 0.5}, # solid 3bet semi-bluff, same reasons as 4bet bluff
    "T8s": {"raise": 0.0, "call": 0.0},

    "98s": {"raise": 0.0, "call": 1.0},
    "97s": {"raise": 0.0, "call": 0.0},

    "87s": {"raise": 0.0, "call": 1/3}, 
    "86s": {"raise": 0.0, "call": 0.0},

    "76s": {"raise": 0.0, "call": 0.0},
    "75s": {"raise": 0.0, "call": 0.0},

    "65s": {"raise": 0.0, "call": 0.0}, 
    
    "54s": {"raise": 0.0, "call": 0.0},

    "43s": {"raise": 0.0, "call": 0.0},

    "32s": {"raise": 0.0, "call": 0.0},
}

# Visualize the range
open_response = range_construction.generate_range(open_response_range, '../ranges/hj_ranges/hj_open_response')
open_response_distribution = range_construction.range_hand_distribution(open_response_range)
open_response_percent_by_actions = range_construction.range_percent_by_all_actions(open_response_range)
open_response_mean_hand_rank = range_construction.average_range_rank(open_response_range)

print(open_response_percent_by_actions)
print(f'Mean hand rank: {open_response_mean_hand_rank}')
print(f'Percent A or K high: {range_construction.percent_range_high_card(open_response_range)} %')
print(f'Defended Flatting range: {range_construction.flat_defense(response_3bet_range, open_response_range)} %')

open_response_distribution[1].to_csv('../ranges/hj_ranges/hj_open_response_distribution.csv')
open_response_distribution[0]
# Out:
# {'raise': {'percent': 7.013574660633484, 'combos': 93.0}, 'call': {'percent': 4.587732528909, 'combos': 60.833333333333336}, 'fold': {'percent': 88.39869281045752, 'combos': 1172.1666666666667}, 'overall': {'percent': 11.601307189542483, 'combos': 153.83333333333334}}
# Mean hand rank: 13.189814814814815
# Percent A or K high: 66.95557963163597 %
# Defended Flatting range: 62.6027397260274 %
# count     29.000000
# mean      21.931034
# std       23.407769
# min        1.000000
# 25%        8.000000
# 50%       15.000000
# 75%       26.000000
# max      100.000000
# Name: Rank, dtype: float64

# %% [markdown]
# # 4! response range

# %% [markdown]
# Given the slightly earlier position, will consider 5bets only in the case of multiple opponents calling the 4bet. If heads up, then will proceed with only calls.

# %%
response_4bet_range = {
    # Pairs
    "AA": {"raise": 1.0, "call": 0.0},
    "KK": {"raise": 1.0, "call": 0.0},
    "QQ": {"raise": 0.33, "call": 0.66},
    "JJ": {"raise": 0, "call": 1.0},
    "TT": {"raise": 0, "call": 1.0},
    "99": {"raise": 0, "call": 0.0},
    "88": {"raise": 0, "call": 0.0},

    "AKs": {"raise": 0, "call": 1.0},
    "AQs": {"raise": 0, "call": 0.0},
    "AJs": {"raise": 0, "call": 0.0},
    "ATs": {"raise": 0, "call": 0.0},

    "AKo": {"raise": 0.0, "call": 1.0},
    "AQo": {"raise": 0.0, "call": 0.0},
    "AJo": {"raise": 0.0, "call": 0.0},
    "ATo": {"raise": 0.0, "call": 0.0},

    "KQs": {"raise": 0.0, "call": 0.0},
    "KJs": {"raise": 0.0, "call": 0.0},

    "KQo": {"raise": 0.0, "call": 0.0},

    "QJs": {"raise": 0.0, "call": 0.0},
    "JTs": {"raise": 0.0, "call": 0.0},
}

response_4bet = range_construction.generate_range(response_4bet_range, '../ranges/hj_ranges/hj_4!response')
response_4bet_distribution = range_construction.range_hand_distribution(response_4bet_range)
response_4bet_percent_by_actions = range_construction.range_percent_by_all_actions(response_4bet_range)
response_4bet_mean_hand_rank = range_construction.average_range_rank(response_4bet_range)

print(response_4bet_percent_by_actions)
print(f'Mean hand rank: {response_4bet_mean_hand_rank}')
print(f'Percent A or K high: {range_construction.percent_range_high_card(response_4bet_range)} %')

defended_3bet = 100*(response_4bet_percent_by_actions['overall']['combos'] / open_response_percent_by_actions['raise']['combos'])
print(f'3bet defended {defended_3bet}')

response_4bet_distribution[1].to_csv('../ranges/hj_ranges/hj_response_4bet_distribution.csv')
response_4bet_distribution[0]
# Out:
# {'raise': {'percent': 1.0542986425339367, 'combos': 13.98}, 'call': {'percent': 2.41025641025641, 'combos': 31.96}, 'fold': {'percent': 96.53544494720965, 'combos': 1280.06}, 'overall': {'percent': 3.464555052790347, 'combos': 45.94}}
# Mean hand rank: 4.37125
# Percent A or K high: 60.9490639965172 %
# 3bet defended 49.39784946236559
# count     7.000000
# mean      5.000000
# std       3.829708
# min       1.000000
# 25%       2.500000
# 50%       4.000000
# 75%       6.500000
# max      12.000000
# Name: Rank, dtype: float64
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
